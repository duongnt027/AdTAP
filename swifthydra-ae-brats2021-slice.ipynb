# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
from torchvision import models

# %%
class NPZDataset(Dataset):
    def __init__(self, path, indices=None, resize=256, device="cpu"):
        self.data = np.load(path, allow_pickle=True, mmap_mode="r")
        self.images = self.data["images"]
        self.labels = self.data["labels"]

        if indices is None:
            self.indices = np.arange(len(self.labels))
        else:
            self.indices = indices

        self.resize = resize
        self.device = device

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        i = self.indices[idx]
        img = torch.tensor(self.images[i]).float()
        lbl = torch.tensor(self.labels[i]).float()

        img = img.permute(2,0,1)
        if img.max() > 1:
            img = img / 255.

        img = F.interpolate(
            img.unsqueeze(0),
            size=(self.resize, self.resize),
            mode="bilinear",
            align_corners=False
        ).squeeze(0)

        return img.to(self.device), lbl.to(self.device)

class SyntheticDataset(Dataset):
    def __init__(self, path, device):
        d = np.load(path)
        self.images = d["images"]
        self.labels = d["labels"]
        self.device = device

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        img = torch.tensor(self.images[idx], dtype=torch.float32).permute(2,0,1)
        lbl = torch.tensor(self.labels[idx], dtype=torch.float32)
        return img.to(self.device), lbl.to(self.device)

# %%
def load_train_test(path, device="cpu", batch_size=32, resize=256, test_size=0.6):
    dataset_full = NPZDataset(path, device=device, resize=resize)
    indices = np.arange(len(dataset_full.labels))

    # Nếu test_size = 0 → không split
    if test_size == 0:
        train_idx = indices
        test_idx = []
    else:
        train_idx, test_idx = train_test_split(
            indices,
            test_size=test_size,
            stratify=dataset_full.labels,
            random_state=42
        )

    train_dataset = NPZDataset(path, indices=train_idx, device=device, resize=resize)
    test_dataset  = NPZDataset(path, indices=test_idx,  device=device, resize=resize) if len(test_idx) > 0 else None

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader  = DataLoader(test_dataset,  batch_size=batch_size) if test_dataset is not None else None

    return train_dataset, train_loader, test_dataset, test_loader

def count_classes(dataset):
    count0 = 0
    count1 = 0
    
    for i in range(len(dataset)):
        lbl = dataset[i][1]    # dataset[i] → (image, label)
        lbl = int(lbl.item())  # convert to 0 hoặc 1
        
        if lbl == 0:
            count0 += 1
        else:
            count1 += 1
    return count0, count1

def evaluate_model(model, loader, device, threshold=0.5):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for x_batch, y_batch in loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            y_pred = model(x_batch).squeeze()
            all_preds.append(y_pred.cpu())
            all_labels.append(y_batch.cpu())

    preds = torch.cat(all_preds).numpy()
    labels = torch.cat(all_labels).numpy()


    binary_pred = (preds > threshold).astype(int)
    
    print("Classification Report:")
    print(classification_report(labels, binary_pred, labels=[0,1], target_names=["Class 0","Class 1"]))

    if len(set(labels)) > 1:
        auc = roc_auc_score(labels, preds)
        print(f"AUC-ROC: {auc:.4f}")
    else:
        print("AUC-ROC: Undefined (only one class present)")

# %%
class ResNetEmbedder(nn.Module):
    def __init__(self, output_dim=128, pretrained=True):
        super().__init__()
        self.backbone = models.resnet50(pretrained=pretrained)
        self.backbone.fc = nn.Identity()
        self.dim_adjuster = nn.Linear(2048, output_dim)
        self.output_dim = output_dim

    def forward(self, images):
        features = self.backbone(images)
        features = features.squeeze()
        if features.dim() == 1:
            features = features.unsqueeze(0)
        features = self.dim_adjuster(features)
        return features

class CNNAutoEncoder(nn.Module):
    def __init__(self, latent_dim=128):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3,64,4,2,1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.Conv2d(64,128,4,2,1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.Conv2d(128,256,4,2,1), nn.BatchNorm2d(256), nn.ReLU(),
            nn.Conv2d(256,512,4,2,1), nn.BatchNorm2d(512), nn.ReLU()
        )
        self.encoder2latent = nn.Linear(512*16*16+1, latent_dim)
        self.latent2decoder = nn.Linear(latent_dim+1, 512*16*16)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(512,256,4,2,1), nn.BatchNorm2d(256), nn.ReLU(),
            nn.ConvTranspose2d(256,128,4,2,1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.ConvTranspose2d(128,64,4,2,1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.ConvTranspose2d(64,3,4,2,1), nn.Sigmoid()
        )

    def encode(self, x, y):
        h = self.encoder(x)
        flat = h.view(x.size(0), -1)
        xy = torch.cat([flat, y], dim=1)
        z = self.encoder2latent(xy)
        return z

    def decode(self, z, y):
        zy = torch.cat([z, y], dim=1)
        flat = self.latent2decoder(zy)
        h = flat.view(z.size(0),512,16,16)
        x_recon = self.decoder(h)
        return x_recon

    def forward(self, x, y):
        z = self.encode(x, y)
        return self.decode(z, y)

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0,max_len).unsqueeze(1).float()
        div_term = torch.exp(torch.arange(0,d_model,2).float()*(-np.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(position*div_term)
        pe[:,1::2] = torch.cos(position*div_term)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self,x):
        L = x.size(1)
        return x + self.pe[:,:L,:]

class ViTransformerDetector(nn.Module):
    def __init__(self, embedder, d_model=128, nhead=8, num_layers=2, dim_feedforward=256, dropout=0.1):
        super().__init__()
        self.embedder = embedder
        self.embedding_dim = embedder.output_dim
        self.projection = nn.Linear(self.embedding_dim,d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead,
                                                   dim_feedforward=dim_feedforward,
                                                   dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Sequential(
            nn.Linear(d_model,128), nn.ReLU(), nn.Dropout(dropout),
            nn.Linear(128,1), nn.Sigmoid()
        )

    def forward(self,x):
        emb = self.embedder(x).view(x.size(0),1,-1)
        emb = self.projection(emb)
        emb = self.positional_encoding(emb)
        h = self.transformer_encoder(emb)
        pooled = h.mean(dim=1)
        return self.fc(pooled).squeeze(1)

class EarlyStopping:
    def __init__(self, patience=5, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float("inf")
        self.early_stop = False

    def step(self, current_loss):
        if current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

    def reset(self):
        self.counter = 0
        self.best_loss = float("inf")
        self.early_stop = False

# %%
def train_cnn_ae(model, loader, opt, device):
    model.train()
    total = 0
    for x,y in loader:
        x = x.to(device)
        y = y.unsqueeze(1).to(device)
        recon = model.decode(model.encode(x,y), y)
        loss = F.mse_loss(recon, x)
        opt.zero_grad()
        loss.backward()
        opt.step()
        total += loss.item()
    return total/len(loader)


def train_detector(model, loader, opt, criterion, device):
    model.train()
    total = 0
    for x,y in loader:
        x=x.to(device); y=y.to(device)
        out = model(x)
        loss = criterion(out, y)
        opt.zero_grad()
        loss.backward()
        opt.step()
        total += loss.item()
    return total/len(loader)

# %%
def One_Step_To_Feasible_Action(generator, detector, x_orig, device,
                                previously_generated=None, alpha=1.0,
                                lambda_div=0.1, lr=0.001, steps=50):
    generator.eval()
    detector.eval()
    if previously_generated is None:
        previously_generated = []

    x_orig = x_orig.to(device).unsqueeze(0)
    y_class1 = torch.full((1,1),0.8,device=device)

    with torch.no_grad():
        z = generator.encode(x_orig, y_class1)
    z = z.clone().detach().requires_grad_(True)

    optimizer_z = torch.optim.Adam([z], lr=lr)

    for step in range(steps):
        optimizer_z.zero_grad()
        x_syn = generator.decode(z, y_class1)
        prob_class1 = detector(x_syn)

        if len(previously_generated) > 0:
            old = torch.stack(previously_generated).to(device)
            diff = x_syn.unsqueeze(1)-old.unsqueeze(0)
            dist_min = diff.norm(p=2,dim=(2,3,4)).min(dim=1).values
            diversity_term = torch.exp(-alpha*dist_min).mean()
        else:
            diversity_term = torch.tensor(0.0, device=device)

        reward = prob_class1.mean() + lambda_div*diversity_term
        reward.backward()
        optimizer_z.step()

    with torch.no_grad():
        x_adv = generator.decode(z, y_class1).detach().cpu()

    return x_adv

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATASET_DIR = "/kaggle/input/bmad-80-20-npz/bmad-npz"
# DATASET_NAME = "camelyon16_256"
DATASET_NAME = "BraTS2021_slice"
# DATASET_NAME = "hist_DIY"
DATASET_PATH = f"{DATASET_DIR}/{DATASET_NAME}/{DATASET_NAME}_train.npz"
SYNTHETIC_DIR = f"synthetics/"
os.makedirs(SYNTHETIC_DIR, exist_ok=True)
MODEL_DIR = f"{DATASET_NAME}_models/"
os.makedirs(MODEL_DIR, exist_ok=True)
PATIENTCE = 5
BATCH_SIZE = 100

train_dataset, train_loader, test_dataset, test_loader = load_train_test(
    DATASET_PATH, device=DEVICE, batch_size=BATCH_SIZE, resize=256
)

generator = CNNAutoEncoder(latent_dim=64).to(DEVICE)
embedder = ResNetEmbedder(output_dim=128).to(DEVICE)
detector = ViTransformerDetector(embedder=embedder).to(DEVICE)
early_stopper = EarlyStopping(patience=PATIENTCE)

optimizer_g = torch.optim.Adam(generator.parameters(), lr=1e-4)
optimizer_d = torch.optim.Adam(detector.parameters(), lr=1e-4)
criterion = nn.BCELoss()

synthetic_files = []
num_epochs_generator = 100
num_epochs_detector = 100
num_episodes = 100
num_gen_data = 50
combined_dataset = train_dataset

for ep in range(num_episodes):
    print(f"\n================ EPISODE {ep+1}/{num_episodes} ================")
    total_class0, total_class1 = count_classes(combined_dataset)
    
    # 2️⃣ Print
    print(f"[Episode {ep+1}] Class count → 0: {total_class0}, 1: {total_class1}")
    
    # 3️⃣ Auto-stop if balanced
    if total_class1 >= total_class0:
        print("Dataset is now balanced. Stopping synthetic generation.")
        break

    # TRAIN GENERATOR
    early_stopper.reset()
    for epoch in range(num_epochs_generator):
        loss_g = train_cnn_ae(generator, train_loader, optimizer_g, DEVICE)
        print(f"[GENERATOR] Epoch {epoch+1}/{num_epochs_generator}, Loss={loss_g:.4f}")
        early_stopper.step(loss_g)
        if early_stopper.early_stop:
            print(f"[GENERATOR] Early stopping at epoch {epoch+1}")
            break

    torch.save(generator.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_generator.pth")

    # 4️⃣ Train detector
    early_stopper.reset()
    for epoch in range(num_epochs_detector):
        loss_d = train_detector(detector, train_loader, optimizer_d, criterion, DEVICE)
        print(f"[DETECTOR] Epoch {epoch+1}/{num_epochs_detector}, Loss={loss_d:.4f}")
        early_stopper.step(loss_d)
        if early_stopper.early_stop:
            print(f"[DETECTOR] Early stopping at epoch {epoch+1}")
            break

    torch.save(detector.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_detector.pth")

    # 5️⃣ Generate synthetic samples (class 1)
    synthetic_samples = []
    idx_class1 = [i for i, idx_lbl in enumerate(train_dataset.indices) if train_dataset.labels[idx_lbl] == 1]

    for _ in range(num_gen_data):
        if not idx_class1:
            break
        rand_idx = np.random.choice(idx_class1)
        x_orig, _ = train_dataset[rand_idx]
        x_adv = One_Step_To_Feasible_Action(generator, detector, x_orig, DEVICE)
        synthetic_samples.append(x_adv.to(DEVICE))

    syn_tensor = torch.cat(synthetic_samples)            # (N,3,H,W)
    syn_tensor_hwc = syn_tensor.permute(0,2,3,1).cpu().numpy()   # (N,H,W,3)  <-- HWC
    syn_labels = np.ones(len(synthetic_samples), dtype=np.float32)
    
    syn_path = f"{SYNTHETIC_DIR}/syn_ep{ep}.npz"
    np.savez_compressed(syn_path, images=syn_tensor_hwc, labels=syn_labels)
    synthetic_files.append(syn_path)

    print(f"[EP {ep}] Generated synthetic saved:", syn_path)

    synthetic_subsets = []
    for f in synthetic_files:
        synthetic_subsets.append(SyntheticDataset(f, DEVICE))
    
    synthetic_full = ConcatDataset(synthetic_subsets)
    combined_dataset = ConcatDataset([train_dataset, synthetic_full])
    
    train_loader = DataLoader(combined_dataset, batch_size=BATCH_SIZE, shuffle=True)
    print(f"[EP {ep}] Train dataset expanded: now {len(combined_dataset)} samples")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 174MB/s]
# ================ EPISODE 1/100 ================
# [Episode 1] Class count → 0: 2617, 1: 998
# [GENERATOR] Epoch 1/100, Loss=0.1399
# [GENERATOR] Epoch 2/100, Loss=0.0679
# [GENERATOR] Epoch 3/100, Loss=0.0430
# [GENERATOR] Epoch 4/100, Loss=0.0291
# [GENERATOR] Epoch 5/100, Loss=0.0208
# [GENERATOR] Epoch 6/100, Loss=0.0155
# [GENERATOR] Epoch 7/100, Loss=0.0122
# [GENERATOR] Epoch 8/100, Loss=0.0100
# [GENERATOR] Epoch 9/100, Loss=0.0086
# [GENERATOR] Epoch 10/100, Loss=0.0075
# [GENERATOR] Epoch 11/100, Loss=0.0067
# [GENERATOR] Epoch 12/100, Loss=0.0061
# [GENERATOR] Epoch 13/100, Loss=0.0057
# [GENERATOR] Epoch 14/100, Loss=0.0052
# [GENERATOR] Epoch 15/100, Loss=0.0049
# [GENERATOR] Epoch 16/100, Loss=0.0046
# [GENERATOR] Epoch 17/100, Loss=0.0044
# [GENERATOR] Epoch 18/100, Loss=0.0042
# [GENERATOR] Epoch 19/100, Loss=0.0041
# [GENERATOR] Epoch 20/100, Loss=0.0039
# [GENERATOR] Epoch 21/100, Loss=0.0038
# [GENERATOR] Epoch 22/100, Loss=0.0037
# [GENERATOR] Epoch 23/100, Loss=0.0036
# [GENERATOR] Epoch 24/100, Loss=0.0034
# [GENERATOR] Epoch 25/100, Loss=0.0034
# [GENERATOR] Epoch 26/100, Loss=0.0034
# [GENERATOR] Epoch 27/100, Loss=0.0032
# [GENERATOR] Epoch 28/100, Loss=0.0031
# [GENERATOR] Epoch 29/100, Loss=0.0031
# [GENERATOR] Epoch 30/100, Loss=0.0031
# [GENERATOR] Epoch 31/100, Loss=0.0030
# [GENERATOR] Epoch 32/100, Loss=0.0030
# [GENERATOR] Epoch 33/100, Loss=0.0030
# [GENERATOR] Epoch 34/100, Loss=0.0029
# [GENERATOR] Epoch 35/100, Loss=0.0028
# [GENERATOR] Epoch 36/100, Loss=0.0028
# [GENERATOR] Epoch 37/100, Loss=0.0028
# [GENERATOR] Epoch 38/100, Loss=0.0027
# [GENERATOR] Epoch 39/100, Loss=0.0027
# [GENERATOR] Epoch 40/100, Loss=0.0026
# [GENERATOR] Epoch 41/100, Loss=0.0026
# [GENERATOR] Epoch 42/100, Loss=0.0026
# [GENERATOR] Epoch 43/100, Loss=0.0026
# [GENERATOR] Epoch 44/100, Loss=0.0025
# [GENERATOR] Epoch 45/100, Loss=0.0025
# [GENERATOR] Epoch 46/100, Loss=0.0025
# [GENERATOR] Epoch 47/100, Loss=0.0025
# [GENERATOR] Epoch 48/100, Loss=0.0025
# [GENERATOR] Epoch 49/100, Loss=0.0024
# [GENERATOR] Epoch 50/100, Loss=0.0024
# [GENERATOR] Epoch 51/100, Loss=0.0024
# [GENERATOR] Epoch 52/100, Loss=0.0024
# [GENERATOR] Epoch 53/100, Loss=0.0024
# [GENERATOR] Epoch 54/100, Loss=0.0024
# [GENERATOR] Early stopping at epoch 54
# [DETECTOR] Epoch 1/100, Loss=0.2968
# [DETECTOR] Epoch 2/100, Loss=0.1408
# [DETECTOR] Epoch 3/100, Loss=0.0888
# [DETECTOR] Epoch 4/100, Loss=0.0633
# [DETECTOR] Epoch 5/100, Loss=0.0290
# [DETECTOR] Epoch 6/100, Loss=0.0219
# [DETECTOR] Epoch 7/100, Loss=0.0364
# [DETECTOR] Epoch 8/100, Loss=0.0349
# [DETECTOR] Epoch 9/100, Loss=0.0251
# [DETECTOR] Epoch 10/100, Loss=0.0131
# [DETECTOR] Epoch 11/100, Loss=0.0067
# [DETECTOR] Epoch 12/100, Loss=0.0123
# [DETECTOR] Epoch 13/100, Loss=0.0074
# [DETECTOR] Epoch 14/100, Loss=0.0078
# [DETECTOR] Epoch 15/100, Loss=0.0162
# [DETECTOR] Epoch 16/100, Loss=0.0182
# [DETECTOR] Early stopping at epoch 16
# [EP 0] Generated synthetic saved: synthetics//syn_ep0.npz
# [EP 0] Train dataset expanded: now 3665 samples
#
# ================ EPISODE 2/100 ================
# [Episode 2] Class count → 0: 2617, 1: 1048
# [GENERATOR] Epoch 1/100, Loss=0.0023
# [GENERATOR] Epoch 2/100, Loss=0.0023
# [GENERATOR] Epoch 3/100, Loss=0.0023
# [GENERATOR] Epoch 4/100, Loss=0.0023
# [GENERATOR] Epoch 5/100, Loss=0.0022
# [GENERATOR] Epoch 6/100, Loss=0.0022
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0049
# [DETECTOR] Epoch 2/100, Loss=0.0063
# [DETECTOR] Epoch 3/100, Loss=0.0064
# [DETECTOR] Epoch 4/100, Loss=0.0439
# [DETECTOR] Epoch 5/100, Loss=0.0132
# [DETECTOR] Epoch 6/100, Loss=0.0043
# [DETECTOR] Epoch 7/100, Loss=0.0043
# [DETECTOR] Epoch 8/100, Loss=0.0061
# [DETECTOR] Epoch 9/100, Loss=0.0070
# [DETECTOR] Epoch 10/100, Loss=0.0046
# [DETECTOR] Epoch 11/100, Loss=0.0059
# [DETECTOR] Early stopping at epoch 11
# [EP 1] Generated synthetic saved: synthetics//syn_ep1.npz
# [EP 1] Train dataset expanded: now 3715 samples
#
# ================ EPISODE 3/100 ================
# [Episode 3] Class count → 0: 2617, 1: 1098
# [GENERATOR] Epoch 1/100, Loss=0.0022
# [GENERATOR] Epoch 2/100, Loss=0.0022
# [GENERATOR] Epoch 3/100, Loss=0.0022
# [GENERATOR] Epoch 4/100, Loss=0.0022
# [GENERATOR] Epoch 5/100, Loss=0.0022
# [GENERATOR] Epoch 6/100, Loss=0.0021
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0013
# [DETECTOR] Epoch 2/100, Loss=0.0007
# [DETECTOR] Epoch 3/100, Loss=0.0005
# [DETECTOR] Epoch 4/100, Loss=0.0004
# [DETECTOR] Epoch 5/100, Loss=0.0004
# [DETECTOR] Epoch 6/100, Loss=0.0004
# [DETECTOR] Epoch 7/100, Loss=0.0003
# [DETECTOR] Epoch 8/100, Loss=0.0192
# [DETECTOR] Epoch 9/100, Loss=0.0734
# [DETECTOR] Epoch 10/100, Loss=0.0156
# [DETECTOR] Early stopping at epoch 10
# [EP 2] Generated synthetic saved: synthetics//syn_ep2.npz
# [EP 2] Train dataset expanded: now 3765 samples
#
# ================ EPISODE 4/100 ================
# [Episode 4] Class count → 0: 2617, 1: 1148
# [GENERATOR] Epoch 1/100, Loss=0.0021
# [GENERATOR] Epoch 2/100, Loss=0.0021
# [GENERATOR] Epoch 3/100, Loss=0.0021
# [GENERATOR] Epoch 4/100, Loss=0.0021
# [GENERATOR] Epoch 5/100, Loss=0.0021
# [GENERATOR] Epoch 6/100, Loss=0.0020
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0136
# [DETECTOR] Epoch 2/100, Loss=0.0025
# [DETECTOR] Epoch 3/100, Loss=0.0016
# [DETECTOR] Epoch 4/100, Loss=0.0006
# [DETECTOR] Epoch 5/100, Loss=0.0003
# [DETECTOR] Epoch 6/100, Loss=0.0003
# [DETECTOR] Epoch 7/100, Loss=0.0003
# [DETECTOR] Epoch 8/100, Loss=0.0002
# [DETECTOR] Epoch 9/100, Loss=0.0003
# [DETECTOR] Epoch 10/100, Loss=0.0002
# [DETECTOR] Epoch 11/100, Loss=0.0004
# [DETECTOR] Epoch 12/100, Loss=0.0021
# [DETECTOR] Epoch 13/100, Loss=0.0070
# [DETECTOR] Epoch 14/100, Loss=0.0028
# [DETECTOR] Epoch 15/100, Loss=0.0076
# [DETECTOR] Early stopping at epoch 15
# [EP 3] Generated synthetic saved: synthetics//syn_ep3.npz
# [EP 3] Train dataset expanded: now 3815 samples
#
# ================ EPISODE 5/100 ================
# [Episode 5] Class count → 0: 2617, 1: 1198
# [GENERATOR] Epoch 1/100, Loss=0.0020
# [GENERATOR] Epoch 2/100, Loss=0.0020
# [GENERATOR] Epoch 3/100, Loss=0.0020
# [GENERATOR] Epoch 4/100, Loss=0.0020
# [GENERATOR] Epoch 5/100, Loss=0.0020
# [GENERATOR] Epoch 6/100, Loss=0.0020
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0011
# [DETECTOR] Epoch 2/100, Loss=0.0028
# [DETECTOR] Epoch 3/100, Loss=0.0089
# [DETECTOR] Epoch 4/100, Loss=0.1063
# [DETECTOR] Epoch 5/100, Loss=0.0145
# [DETECTOR] Epoch 6/100, Loss=0.0228
# [DETECTOR] Early stopping at epoch 6
# [EP 4] Generated synthetic saved: synthetics//syn_ep4.npz
# [EP 4] Train dataset expanded: now 3865 samples
#
# ================ EPISODE 6/100 ================
# [Episode 6] Class count → 0: 2617, 1: 1248
# [GENERATOR] Epoch 1/100, Loss=0.0019
# [GENERATOR] Epoch 2/100, Loss=0.0019
# [GENERATOR] Epoch 3/100, Loss=0.0019
# [GENERATOR] Epoch 4/100, Loss=0.0019
# [GENERATOR] Epoch 5/100, Loss=0.0019
# [GENERATOR] Epoch 6/100, Loss=0.0018
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0039
# [DETECTOR] Epoch 2/100, Loss=0.0024
# [DETECTOR] Epoch 3/100, Loss=0.0034
# [DETECTOR] Epoch 4/100, Loss=0.0013
# [DETECTOR] Epoch 5/100, Loss=0.0051
# [DETECTOR] Epoch 6/100, Loss=0.0083
# [DETECTOR] Epoch 7/100, Loss=0.0039
# [DETECTOR] Epoch 8/100, Loss=0.0031
# [DETECTOR] Epoch 9/100, Loss=0.0061
# [DETECTOR] Early stopping at epoch 9
# [EP 5] Generated synthetic saved: synthetics//syn_ep5.npz
# [EP 5] Train dataset expanded: now 3915 samples
#
# ================ EPISODE 7/100 ================
# [Episode 7] Class count → 0: 2617, 1: 1298
# [GENERATOR] Epoch 1/100, Loss=0.0018
# [GENERATOR] Epoch 2/100, Loss=0.0019
# [GENERATOR] Epoch 3/100, Loss=0.0019
# [GENERATOR] Epoch 4/100, Loss=0.0018
# [GENERATOR] Epoch 5/100, Loss=0.0018
# [GENERATOR] Epoch 6/100, Loss=0.0018
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0076
# [DETECTOR] Epoch 2/100, Loss=0.0179
# [DETECTOR] Epoch 3/100, Loss=0.0038
# [DETECTOR] Epoch 4/100, Loss=0.0017
# [DETECTOR] Epoch 5/100, Loss=0.0004
# [DETECTOR] Epoch 6/100, Loss=0.0002
# [DETECTOR] Epoch 7/100, Loss=0.0002
# [DETECTOR] Epoch 8/100, Loss=0.0002
# [DETECTOR] Epoch 9/100, Loss=0.0001
# [DETECTOR] Epoch 10/100, Loss=0.0001
# [DETECTOR] Epoch 11/100, Loss=0.0001
# [DETECTOR] Early stopping at epoch 11
# [EP 6] Generated synthetic saved: synthetics//syn_ep6.npz
# [EP 6] Train dataset expanded: now 3965 samples
#
# ================ EPISODE 8/100 ================
# [Episode 8] Class count → 0: 2617, 1: 1348
# [GENERATOR] Epoch 1/100, Loss=0.0018
# [GENERATOR] Epoch 2/100, Loss=0.0018
# [GENERATOR] Epoch 3/100, Loss=0.0017
# [GENERATOR] Epoch 4/100, Loss=0.0017
# [GENERATOR] Epoch 5/100, Loss=0.0017
# [GENERATOR] Epoch 6/100, Loss=0.0017
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0001
# [DETECTOR] Epoch 2/100, Loss=0.0002
# [DETECTOR] Epoch 3/100, Loss=0.0001
# [DETECTOR] Epoch 4/100, Loss=0.0001
# [DETECTOR] Epoch 5/100, Loss=0.0001
# [DETECTOR] Epoch 6/100, Loss=0.0001
# [DETECTOR] Early stopping at epoch 6
# [EP 7] Generated synthetic saved: synthetics//syn_ep7.npz
# [EP 7] Train dataset expanded: now 4015 samples
#
# ================ EPISODE 9/100 ================
# [Episode 9] Class count → 0: 2617, 1: 1398
# [GENERATOR] Epoch 1/100, Loss=0.0017
# [GENERATOR] Epoch 2/100, Loss=0.0017
# [GENERATOR] Epoch 3/100, Loss=0.0017
# [GENERATOR] Epoch 4/100, Loss=0.0017
# [GENERATOR] Epoch 5/100, Loss=0.0017
# [GENERATOR] Epoch 6/100, Loss=0.0016
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0001
# [DETECTOR] Epoch 2/100, Loss=0.0001
# [DETECTOR] Epoch 3/100, Loss=0.0001
# [DETECTOR] Epoch 4/100, Loss=0.0001
# [DETECTOR] Epoch 5/100, Loss=0.0001
# [DETECTOR] Epoch 6/100, Loss=0.0001
# [DETECTOR] Early stopping at epoch 6
# [EP 8] Generated synthetic saved: synthetics//syn_ep8.npz
# [EP 8] Train dataset expanded: now 4065 samples
#
# ================ EPISODE 10/100 ================
# [Episode 10] Class count → 0: 2617, 1: 1448
# [GENERATOR] Epoch 1/100, Loss=0.0016
# [GENERATOR] Epoch 2/100, Loss=0.0016
# [GENERATOR] Epoch 3/100, Loss=0.0016
# [GENERATOR] Epoch 4/100, Loss=0.0016
# [GENERATOR] Epoch 5/100, Loss=0.0016
# [GENERATOR] Epoch 6/100, Loss=0.0016
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0001
# [DETECTOR] Epoch 2/100, Loss=0.0001
# [DETECTOR] Epoch 3/100, Loss=0.0001
# [DETECTOR] Epoch 4/100, Loss=0.0001
# [DETECTOR] Epoch 5/100, Loss=0.0001
# [DETECTOR] Epoch 6/100, Loss=0.0001
# [DETECTOR] Early stopping at epoch 6
# [EP 9] Generated synthetic saved: synthetics//syn_ep9.npz
# [EP 9] Train dataset expanded: now 4115 samples
#
# ================ EPISODE 11/100 ================
# [Episode 11] Class count → 0: 2617, 1: 1498
# [GENERATOR] Epoch 1/100, Loss=0.0016
# [GENERATOR] Epoch 2/100, Loss=0.0016
# [GENERATOR] Epoch 3/100, Loss=0.0015
# [GENERATOR] Epoch 4/100, Loss=0.0016
# [GENERATOR] Epoch 5/100, Loss=0.0016
# [GENERATOR] Epoch 6/100, Loss=0.0015
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0139
# [DETECTOR] Epoch 6/100, Loss=0.0246
# [DETECTOR] Early stopping at epoch 6
# [EP 10] Generated synthetic saved: synthetics//syn_ep10.npz
# [EP 10] Train dataset expanded: now 4165 samples
#
# ================ EPISODE 12/100 ================
# [Episode 12] Class count → 0: 2617, 1: 1548
# [GENERATOR] Epoch 1/100, Loss=0.0015
# [GENERATOR] Epoch 2/100, Loss=0.0015
# [GENERATOR] Epoch 3/100, Loss=0.0015
# [GENERATOR] Epoch 4/100, Loss=0.0015
# [GENERATOR] Epoch 5/100, Loss=0.0015
# [GENERATOR] Epoch 6/100, Loss=0.0015
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0130
# [DETECTOR] Epoch 2/100, Loss=0.0057
# [DETECTOR] Epoch 3/100, Loss=0.0016
# [DETECTOR] Epoch 4/100, Loss=0.0003
# [DETECTOR] Epoch 5/100, Loss=0.0010
# [DETECTOR] Epoch 6/100, Loss=0.0109
# [DETECTOR] Epoch 7/100, Loss=0.0187
# [DETECTOR] Epoch 8/100, Loss=0.0067
# [DETECTOR] Epoch 9/100, Loss=0.0015
# [DETECTOR] Early stopping at epoch 9
# [EP 11] Generated synthetic saved: synthetics//syn_ep11.npz
# [EP 11] Train dataset expanded: now 4215 samples
#
# ================ EPISODE 13/100 ================
# [Episode 13] Class count → 0: 2617, 1: 1598
# [GENERATOR] Epoch 1/100, Loss=0.0014
# [GENERATOR] Epoch 2/100, Loss=0.0014
# [GENERATOR] Epoch 3/100, Loss=0.0015
# [GENERATOR] Epoch 4/100, Loss=0.0014
# [GENERATOR] Epoch 5/100, Loss=0.0015
# [GENERATOR] Epoch 6/100, Loss=0.0016
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0016
# [DETECTOR] Epoch 2/100, Loss=0.0002
# [DETECTOR] Epoch 3/100, Loss=0.0001
# [DETECTOR] Epoch 4/100, Loss=0.0001
# [DETECTOR] Epoch 5/100, Loss=0.0001
# [DETECTOR] Epoch 6/100, Loss=0.0001
# [DETECTOR] Epoch 7/100, Loss=0.0001
# [DETECTOR] Epoch 8/100, Loss=0.0001
# [DETECTOR] Epoch 9/100, Loss=0.0001
# [DETECTOR] Early stopping at epoch 9
# [EP 12] Generated synthetic saved: synthetics//syn_ep12.npz
# [EP 12] Train dataset expanded: now 4265 samples
#
# ================ EPISODE 14/100 ================
# [Episode 14] Class count → 0: 2617, 1: 1648
# [GENERATOR] Epoch 1/100, Loss=0.0014
# [GENERATOR] Epoch 2/100, Loss=0.0014
# [GENERATOR] Epoch 3/100, Loss=0.0014
# [GENERATOR] Epoch 4/100, Loss=0.0014
# [GENERATOR] Epoch 5/100, Loss=0.0014
# [GENERATOR] Epoch 6/100, Loss=0.0014
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0001
# [DETECTOR] Epoch 2/100, Loss=0.0001
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 13] Generated synthetic saved: synthetics//syn_ep13.npz
# [EP 13] Train dataset expanded: now 4315 samples
#
# ================ EPISODE 15/100 ================
# [Episode 15] Class count → 0: 2617, 1: 1698
# [GENERATOR] Epoch 1/100, Loss=0.0014
# [GENERATOR] Epoch 2/100, Loss=0.0014
# [GENERATOR] Epoch 3/100, Loss=0.0014
# [GENERATOR] Epoch 4/100, Loss=0.0013
# [GENERATOR] Epoch 5/100, Loss=0.0014
# [GENERATOR] Epoch 6/100, Loss=0.0013
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 14] Generated synthetic saved: synthetics//syn_ep14.npz
# [EP 14] Train dataset expanded: now 4365 samples
#
# ================ EPISODE 16/100 ================
# [Episode 16] Class count → 0: 2617, 1: 1748
# [GENERATOR] Epoch 1/100, Loss=0.0013
# [GENERATOR] Epoch 2/100, Loss=0.0013
# [GENERATOR] Epoch 3/100, Loss=0.0013
# [GENERATOR] Epoch 4/100, Loss=0.0013
# [GENERATOR] Epoch 5/100, Loss=0.0013
# [GENERATOR] Epoch 6/100, Loss=0.0013
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 15] Generated synthetic saved: synthetics//syn_ep15.npz
# [EP 15] Train dataset expanded: now 4415 samples
#
# ================ EPISODE 17/100 ================
# [Episode 17] Class count → 0: 2617, 1: 1798
# [GENERATOR] Epoch 1/100, Loss=0.0012
# [GENERATOR] Epoch 2/100, Loss=0.0013
# [GENERATOR] Epoch 3/100, Loss=0.0013
# [GENERATOR] Epoch 4/100, Loss=0.0013
# [GENERATOR] Epoch 5/100, Loss=0.0013
# [GENERATOR] Epoch 6/100, Loss=0.0013
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 16] Generated synthetic saved: synthetics//syn_ep16.npz
# [EP 16] Train dataset expanded: now 4465 samples
#
# ================ EPISODE 18/100 ================
# [Episode 18] Class count → 0: 2617, 1: 1848
# [GENERATOR] Epoch 1/100, Loss=0.0012
# [GENERATOR] Epoch 2/100, Loss=0.0012
# [GENERATOR] Epoch 3/100, Loss=0.0012
# [GENERATOR] Epoch 4/100, Loss=0.0012
# [GENERATOR] Epoch 5/100, Loss=0.0012
# [GENERATOR] Epoch 6/100, Loss=0.0012
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 17] Generated synthetic saved: synthetics//syn_ep17.npz
# [EP 17] Train dataset expanded: now 4515 samples
#
# ================ EPISODE 19/100 ================
# [Episode 19] Class count → 0: 2617, 1: 1898
# [GENERATOR] Epoch 1/100, Loss=0.0012
# [GENERATOR] Epoch 2/100, Loss=0.0012
# [GENERATOR] Epoch 3/100, Loss=0.0012
# [GENERATOR] Epoch 4/100, Loss=0.0012
# [GENERATOR] Epoch 5/100, Loss=0.0012
# [GENERATOR] Epoch 6/100, Loss=0.0012
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 18] Generated synthetic saved: synthetics//syn_ep18.npz
# [EP 18] Train dataset expanded: now 4565 samples
#
# ================ EPISODE 20/100 ================
# [Episode 20] Class count → 0: 2617, 1: 1948
# [GENERATOR] Epoch 1/100, Loss=0.0011
# [GENERATOR] Epoch 2/100, Loss=0.0012
# [GENERATOR] Epoch 3/100, Loss=0.0011
# [GENERATOR] Epoch 4/100, Loss=0.0011
# [GENERATOR] Epoch 5/100, Loss=0.0011
# [GENERATOR] Epoch 6/100, Loss=0.0011
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 19] Generated synthetic saved: synthetics//syn_ep19.npz
# [EP 19] Train dataset expanded: now 4615 samples
#
# ================ EPISODE 21/100 ================
# [Episode 21] Class count → 0: 2617, 1: 1998
# [GENERATOR] Epoch 1/100, Loss=0.0011
# [GENERATOR] Epoch 2/100, Loss=0.0011
# [GENERATOR] Epoch 3/100, Loss=0.0011
# [GENERATOR] Epoch 4/100, Loss=0.0011
# [GENERATOR] Epoch 5/100, Loss=0.0011
# [GENERATOR] Epoch 6/100, Loss=0.0011
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 20] Generated synthetic saved: synthetics//syn_ep20.npz
# [EP 20] Train dataset expanded: now 4665 samples
#
# ================ EPISODE 22/100 ================
# [Episode 22] Class count → 0: 2617, 1: 2048
# [GENERATOR] Epoch 1/100, Loss=0.0011
# [GENERATOR] Epoch 2/100, Loss=0.0011
# [GENERATOR] Epoch 3/100, Loss=0.0011
# [GENERATOR] Epoch 4/100, Loss=0.0011
# [GENERATOR] Epoch 5/100, Loss=0.0010
# [GENERATOR] Epoch 6/100, Loss=0.0011
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0002
# [DETECTOR] Epoch 2/100, Loss=0.0484
# [DETECTOR] Epoch 3/100, Loss=0.0252
# [DETECTOR] Epoch 4/100, Loss=0.0052
# [DETECTOR] Epoch 5/100, Loss=0.0098
# [DETECTOR] Epoch 6/100, Loss=0.0081
# [DETECTOR] Early stopping at epoch 6
# [EP 21] Generated synthetic saved: synthetics//syn_ep21.npz
# [EP 21] Train dataset expanded: now 4715 samples
#
# ================ EPISODE 23/100 ================
# [Episode 23] Class count → 0: 2617, 1: 2098
# [GENERATOR] Epoch 1/100, Loss=0.0010
# [GENERATOR] Epoch 2/100, Loss=0.0010
# [GENERATOR] Epoch 3/100, Loss=0.0011
# [GENERATOR] Epoch 4/100, Loss=0.0011
# [GENERATOR] Epoch 5/100, Loss=0.0011
# [GENERATOR] Epoch 6/100, Loss=0.0011
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0087
# [DETECTOR] Epoch 2/100, Loss=0.0007
# [DETECTOR] Epoch 3/100, Loss=0.0002
# [DETECTOR] Epoch 4/100, Loss=0.0001
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Epoch 7/100, Loss=0.0000
# [DETECTOR] Epoch 8/100, Loss=0.0000
# [DETECTOR] Epoch 9/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 9
# [EP 22] Generated synthetic saved: synthetics//syn_ep22.npz
# [EP 22] Train dataset expanded: now 4765 samples
#
# ================ EPISODE 24/100 ================
# [Episode 24] Class count → 0: 2617, 1: 2148
# [GENERATOR] Epoch 1/100, Loss=0.0011
# [GENERATOR] Epoch 2/100, Loss=0.0010
# [GENERATOR] Epoch 3/100, Loss=0.0010
# [GENERATOR] Epoch 4/100, Loss=0.0010
# [GENERATOR] Epoch 5/100, Loss=0.0010
# [GENERATOR] Epoch 6/100, Loss=0.0010
# [GENERATOR] Epoch 7/100, Loss=0.0010
# [GENERATOR] Early stopping at epoch 7
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 23] Generated synthetic saved: synthetics//syn_ep23.npz
# [EP 23] Train dataset expanded: now 4815 samples
#
# ================ EPISODE 25/100 ================
# [Episode 25] Class count → 0: 2617, 1: 2198
# [GENERATOR] Epoch 1/100, Loss=0.0010
# [GENERATOR] Epoch 2/100, Loss=0.0010
# [GENERATOR] Epoch 3/100, Loss=0.0010
# [GENERATOR] Epoch 4/100, Loss=0.0010
# [GENERATOR] Epoch 5/100, Loss=0.0010
# [GENERATOR] Epoch 6/100, Loss=0.0010
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 24] Generated synthetic saved: synthetics//syn_ep24.npz
# [EP 24] Train dataset expanded: now 4865 samples
#
# ================ EPISODE 26/100 ================
# [Episode 26] Class count → 0: 2617, 1: 2248
# [GENERATOR] Epoch 1/100, Loss=0.0010
# [GENERATOR] Epoch 2/100, Loss=0.0010
# [GENERATOR] Epoch 3/100, Loss=0.0010
# [GENERATOR] Epoch 4/100, Loss=0.0010
# [GENERATOR] Epoch 5/100, Loss=0.0010
# [GENERATOR] Epoch 6/100, Loss=0.0010
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 25] Generated synthetic saved: synthetics//syn_ep25.npz
# [EP 25] Train dataset expanded: now 4915 samples
#
# ================ EPISODE 27/100 ================
# [Episode 27] Class count → 0: 2617, 1: 2298
# [GENERATOR] Epoch 1/100, Loss=0.0009
# [GENERATOR] Epoch 2/100, Loss=0.0009
# [GENERATOR] Epoch 3/100, Loss=0.0010
# [GENERATOR] Epoch 4/100, Loss=0.0009
# [GENERATOR] Epoch 5/100, Loss=0.0009
# [GENERATOR] Epoch 6/100, Loss=0.0009
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0007
# [DETECTOR] Epoch 5/100, Loss=0.0499
# [DETECTOR] Epoch 6/100, Loss=0.0095
# [DETECTOR] Early stopping at epoch 6
# [EP 26] Generated synthetic saved: synthetics//syn_ep26.npz
# [EP 26] Train dataset expanded: now 4965 samples
#
# ================ EPISODE 28/100 ================
# [Episode 28] Class count → 0: 2617, 1: 2348
# [GENERATOR] Epoch 1/100, Loss=0.0009
# [GENERATOR] Epoch 2/100, Loss=0.0009
# [GENERATOR] Epoch 3/100, Loss=0.0009
# [GENERATOR] Epoch 4/100, Loss=0.0009
# [GENERATOR] Epoch 5/100, Loss=0.0009
# [GENERATOR] Epoch 6/100, Loss=0.0009
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0187
# [DETECTOR] Epoch 2/100, Loss=0.0066
# [DETECTOR] Epoch 3/100, Loss=0.0005
# [DETECTOR] Epoch 4/100, Loss=0.0001
# [DETECTOR] Epoch 5/100, Loss=0.0001
# [DETECTOR] Epoch 6/100, Loss=0.0001
# [DETECTOR] Epoch 7/100, Loss=0.0001
# [DETECTOR] Epoch 8/100, Loss=0.0000
# [DETECTOR] Epoch 9/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 9
# [EP 27] Generated synthetic saved: synthetics//syn_ep27.npz
# [EP 27] Train dataset expanded: now 5015 samples
#
# ================ EPISODE 29/100 ================
# [Episode 29] Class count → 0: 2617, 1: 2398
# [GENERATOR] Epoch 1/100, Loss=0.0009
# [GENERATOR] Epoch 2/100, Loss=0.0009
# [GENERATOR] Epoch 3/100, Loss=0.0009
# [GENERATOR] Epoch 4/100, Loss=0.0009
# [GENERATOR] Epoch 5/100, Loss=0.0009
# [GENERATOR] Epoch 6/100, Loss=0.0009
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 28] Generated synthetic saved: synthetics//syn_ep28.npz
# [EP 28] Train dataset expanded: now 5065 samples
#
# ================ EPISODE 30/100 ================
# [Episode 30] Class count → 0: 2617, 1: 2448
# [GENERATOR] Epoch 1/100, Loss=0.0009
# [GENERATOR] Epoch 2/100, Loss=0.0009
# [GENERATOR] Epoch 3/100, Loss=0.0009
# [GENERATOR] Epoch 4/100, Loss=0.0009
# [GENERATOR] Epoch 5/100, Loss=0.0009
# [GENERATOR] Epoch 6/100, Loss=0.0009
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 29] Generated synthetic saved: synthetics//syn_ep29.npz
# [EP 29] Train dataset expanded: now 5115 samples
#
# ================ EPISODE 31/100 ================
# [Episode 31] Class count → 0: 2617, 1: 2498
# [GENERATOR] Epoch 1/100, Loss=0.0009
# [GENERATOR] Epoch 2/100, Loss=0.0009
# [GENERATOR] Epoch 3/100, Loss=0.0008
# [GENERATOR] Epoch 4/100, Loss=0.0008
# [GENERATOR] Epoch 5/100, Loss=0.0009
# [GENERATOR] Epoch 6/100, Loss=0.0009
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 30] Generated synthetic saved: synthetics//syn_ep30.npz
# [EP 30] Train dataset expanded: now 5165 samples
#
# ================ EPISODE 32/100 ================
# [Episode 32] Class count → 0: 2617, 1: 2548
# [GENERATOR] Epoch 1/100, Loss=0.0009
# [GENERATOR] Epoch 2/100, Loss=0.0008
# [GENERATOR] Epoch 3/100, Loss=0.0008
# [GENERATOR] Epoch 4/100, Loss=0.0008
# [GENERATOR] Epoch 5/100, Loss=0.0008
# [GENERATOR] Epoch 6/100, Loss=0.0008
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0000
# [DETECTOR] Epoch 3/100, Loss=0.0000
# [DETECTOR] Epoch 4/100, Loss=0.0000
# [DETECTOR] Epoch 5/100, Loss=0.0000
# [DETECTOR] Epoch 6/100, Loss=0.0000
# [DETECTOR] Early stopping at epoch 6
# [EP 31] Generated synthetic saved: synthetics//syn_ep31.npz
# [EP 31] Train dataset expanded: now 5215 samples
#
# ================ EPISODE 33/100 ================
# [Episode 33] Class count → 0: 2617, 1: 2598
# [GENERATOR] Epoch 1/100, Loss=0.0008
# [GENERATOR] Epoch 2/100, Loss=0.0008
# [GENERATOR] Epoch 3/100, Loss=0.0008
# [GENERATOR] Epoch 4/100, Loss=0.0008
# [GENERATOR] Epoch 5/100, Loss=0.0009
# [GENERATOR] Epoch 6/100, Loss=0.0009
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0000
# [DETECTOR] Epoch 2/100, Loss=0.0171
# [DETECTOR] Epoch 3/100, Loss=0.0208
# [DETECTOR] Epoch 4/100, Loss=0.0023
# [DETECTOR] Epoch 5/100, Loss=0.0084
# [DETECTOR] Epoch 6/100, Loss=0.0008
# [DETECTOR] Early stopping at epoch 6
# [EP 32] Generated synthetic saved: synthetics//syn_ep32.npz
# [EP 32] Train dataset expanded: now 5265 samples
#
# ================ EPISODE 34/100 ================
# [Episode 34] Class count → 0: 2617, 1: 2648
# Dataset is now balanced. Stopping synthetic generation.

# %%
final_detector = ViTransformerDetector(embedder=embedder).to(DEVICE)
optimizer_final = torch.optim.Adam(final_detector.parameters(), lr=1e-3)
criterion = nn.BCELoss()
num_epochs_final = 100
early_stopper.reset()

for epoch in range(num_epochs_final):
    loss = train_detector(final_detector, train_loader, optimizer_final, criterion, DEVICE)
    print(f"[FINAL DETECTOR] Epoch {epoch+1}/{num_epochs_final}, Loss={loss:.4f}")

    # Check early stopping
    early_stopper.step(loss)
    
    if early_stopper.early_stop:
        print(f"[FINAL DETECTOR] Early stopping at epoch {epoch+1}")
        break
# Out:
# [FINAL DETECTOR] Epoch 1/100, Loss=0.1764
# [FINAL DETECTOR] Epoch 2/100, Loss=0.0976
# [FINAL DETECTOR] Epoch 3/100, Loss=0.0933
# [FINAL DETECTOR] Epoch 4/100, Loss=0.0664
# [FINAL DETECTOR] Epoch 5/100, Loss=0.0787
# [FINAL DETECTOR] Epoch 6/100, Loss=0.0650
# [FINAL DETECTOR] Epoch 7/100, Loss=0.0303
# [FINAL DETECTOR] Epoch 8/100, Loss=0.0360
# [FINAL DETECTOR] Epoch 9/100, Loss=0.0308
# [FINAL DETECTOR] Epoch 10/100, Loss=0.0405
# [FINAL DETECTOR] Epoch 11/100, Loss=0.0283
# [FINAL DETECTOR] Epoch 12/100, Loss=0.0585
# [FINAL DETECTOR] Epoch 13/100, Loss=0.0653
# [FINAL DETECTOR] Epoch 14/100, Loss=0.0268
# [FINAL DETECTOR] Epoch 15/100, Loss=0.0242
# [FINAL DETECTOR] Epoch 16/100, Loss=0.0275
# [FINAL DETECTOR] Epoch 17/100, Loss=0.0221
# [FINAL DETECTOR] Epoch 18/100, Loss=0.0128
# [FINAL DETECTOR] Epoch 19/100, Loss=0.0122
# [FINAL DETECTOR] Epoch 20/100, Loss=0.0084
# [FINAL DETECTOR] Epoch 21/100, Loss=0.0195
# [FINAL DETECTOR] Epoch 22/100, Loss=0.0691
# [FINAL DETECTOR] Epoch 23/100, Loss=0.0483
# [FINAL DETECTOR] Epoch 24/100, Loss=0.0153
# [FINAL DETECTOR] Epoch 25/100, Loss=0.0158
# [FINAL DETECTOR] Early stopping at epoch 25

# %%
evaluate_model(final_detector, test_loader, DEVICE, threshold=0.3)

# Save final detector
torch.save(final_detector.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_detector_final.pth")
print(f"Final detector saved to {MODEL_DIR}/{DATASET_NAME}_detector_final.pth")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.94      0.96      3926
#      Class 1       0.85      0.94      0.90      1497
#
#     accuracy                           0.94      5423
#    macro avg       0.92      0.94      0.93      5423
# weighted avg       0.94      0.94      0.94      5423
#
# AUC-ROC: 0.9833
# Final detector saved to BraTS2021_slice_models//BraTS2021_slice_detector_final.pth

# %%
import shutil

synthetics_folder = "/kaggle/working/synthetics"
synthetics_zip = f"{DATASET_NAME}_synthetics"

shutil.make_archive(synthetics_zip, 'zip', synthetics_folder)
# Out:
# '/kaggle/working/BraTS2021_slice_synthetics.zip'

# %%
import shutil

models_folder = f"/kaggle/working/{DATASET_NAME}_models"
models_zip = f"{DATASET_NAME}_models"

shutil.make_archive(models_zip, 'zip', models_folder)
# Out:
# '/kaggle/working/BraTS2021_slice_models.zip'

# %%
f
# Out:
# 'synthetics//syn_ep32.npz'

# %%
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import TensorDataset

def preview_images(loader, model=None, device='cpu', num_images=5):
    for images, labels in loader:
        images = images[:num_images]
        labels = labels[:num_images]

        if model is None:
            # Chỉ hiển thị ảnh
            imgs_np = images.cpu().numpy()
            labels_np = labels.cpu().numpy()
            imgs_np = np.clip(imgs_np, 0, 1)
            n = imgs_np.shape[0]
            fig, axes = plt.subplots(1, n, figsize=(3*n, 3))
            if n == 1:
                axes = [axes]
            for j in range(n):
                label = int(labels_np[j])
                axes[j].imshow(imgs_np[j].transpose(1, 2, 0))
                axes[j].set_title(f'[{label}] Image {j}')
                axes[j].axis('off')
            plt.tight_layout()
            plt.show()
        else:
            # Hiển thị Original vs Reconstructed
            model.eval()
            with torch.no_grad():
                images = images.to(device)
                labels = labels.to(device)
                reconstructed, _, _ = model(images, labels.unsqueeze(1))

            orig = images.cpu().numpy()
            recon = reconstructed.cpu().numpy()
            labels_np = labels.cpu().numpy()
            orig = np.clip(orig, 0, 1)
            recon = np.clip(recon, 0, 1)

            n = orig.shape[0]
            fig, axes = plt.subplots(2, n, figsize=(4*n, 8))
            if n == 1:
                axes = axes.reshape(2, 1)

            for j in range(n):
                label = int(labels_np[j])
                axes[0, j].imshow(orig[j].transpose(1, 2, 0))
                axes[0, j].set_title(f'[{label}] Org-{j}')
                axes[0, j].axis('off')

                axes[1, j].imshow(recon[j].transpose(1, 2, 0))
                axes[1, j].set_title(f'[{label}] Recon-{j}')
                axes[1, j].axis('off')
            plt.tight_layout()
            plt.show()

        break  # chỉ lấy 1 batch

def load_data(data, batch_num=64, is_shuffle=True):
    images = data['images']  # shape: (N, H, W, C)
    labels = data['labels']

    # Define transform
    transform = transforms.Compose([
        transforms.ToPILImage(),            # Chuyển numpy array -> PIL Image
        transforms.Resize((256, 256)),      # Resize về 256x256
        transforms.ToTensor()               # Chuyển PIL Image -> Tensor [0,1]
    ])

    # Áp dụng transform cho từng ảnh
    X = torch.stack([transform(img) for img in images])

    # Chuyển labels sang tensor
    y = torch.tensor(labels, dtype=torch.float32)

    # Tạo dataset & dataloader
    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=batch_num, shuffle=is_shuffle)

    return loader

# %%
syn_data = np.load("/kaggle/working/synthetics/syn_ep9.npz")
syn_loader = load_data(syn_data)

# %%
preview_images(syn_loader)

# %%
t_data = np.load(f"{DATASET_DIR}/{DATASET_NAME}/{DATASET_NAME}_valid.npz", allow_pickle=True)
t_loader = load_data(t_data)

# %%
preview_images(t_loader)
