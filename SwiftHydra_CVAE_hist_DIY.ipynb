# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
from torchvision import models

# %%
class NPZDataset(Dataset):
    def __init__(self, path, indices=None, resize=256, device="cpu"):
        self.data = np.load(path, allow_pickle=True, mmap_mode="r")
        self.images = self.data["images"]
        self.labels = self.data["labels"]

        if indices is None:
            self.indices = np.arange(len(self.labels))
        else:
            self.indices = indices

        self.resize = resize
        self.device = device

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        i = self.indices[idx]
        img = torch.tensor(self.images[i]).float()
        lbl = torch.tensor(self.labels[i]).float()

        img = img.permute(2,0,1)
        if img.max() > 1:
            img = img / 255.

        img = F.interpolate(
            img.unsqueeze(0),
            size=(self.resize, self.resize),
            mode="bilinear",
            align_corners=False
        ).squeeze(0)

        return img.to(self.device), lbl.to(self.device)

class SyntheticDataset(Dataset):
    def __init__(self, path, device):
        d = np.load(path)
        self.images = d["images"]
        self.labels = d["labels"]
        self.device = device

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        img = torch.tensor(self.images[idx], dtype=torch.float32).permute(2,0,1)
        lbl = torch.tensor(self.labels[idx], dtype=torch.float32)
        return img.to(self.device), lbl.to(self.device)

# %%
def load_train_test(path, device="cpu", batch_size=32, resize=256, test_size=0.6):
    dataset_full = NPZDataset(path, device=device, resize=resize)
    indices = np.arange(len(dataset_full.labels))

    # Nếu test_size = 0 → không split
    if test_size == 0:
        train_idx = indices
        test_idx = []
    else:
        train_idx, test_idx = train_test_split(
            indices,
            test_size=test_size,
            stratify=dataset_full.labels,
            random_state=42
        )

    train_dataset = NPZDataset(path, indices=train_idx, device=device, resize=resize)
    test_dataset  = NPZDataset(path, indices=test_idx,  device=device, resize=resize) if len(test_idx) > 0 else None

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader  = DataLoader(test_dataset,  batch_size=batch_size) if test_dataset is not None else None

    return train_dataset, train_loader, test_dataset, test_loader

def count_classes(dataset):
    count0 = 0
    count1 = 0

    for i in range(len(dataset)):
        lbl = dataset[i][1]    # dataset[i] → (image, label)
        lbl = int(lbl.item())  # convert to 0 hoặc 1

        if lbl == 0:
            count0 += 1
        else:
            count1 += 1
    return count0, count1

def evaluate_model(model, loader, device, threshold=0.5):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for x_batch, y_batch in loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            y_pred = model(x_batch).squeeze()
            all_preds.append(y_pred.cpu())
            all_labels.append(y_batch.cpu())

    preds = torch.cat(all_preds).numpy()
    labels = torch.cat(all_labels).numpy()


    binary_pred = (preds > threshold).astype(int)

    print("Classification Report:")
    print(classification_report(labels, binary_pred, labels=[0,1], target_names=["Class 0","Class 1"]))

    if len(set(labels)) > 1:
        auc = roc_auc_score(labels, preds)
        print(f"AUC-ROC: {auc:.4f}")
    else:
        print("AUC-ROC: Undefined (only one class present)")

# %%
class ResNetEmbedder(nn.Module):
    def __init__(self, output_dim=128, pretrained=True):
        super().__init__()
        self.backbone = models.resnet50(pretrained=pretrained)
        self.backbone.fc = nn.Identity()
        self.dim_adjuster = nn.Linear(2048, output_dim)
        self.output_dim = output_dim

    def forward(self, images):
        features = self.backbone(images)
        features = features.squeeze()
        if features.dim() == 1:
            features = features.unsqueeze(0)
        features = self.dim_adjuster(features)
        return features

class CnnCVAE(nn.Module):
    def __init__(self, latent_dim=128):
        super(CnnCVAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1),  # 128x128x64
            nn.BatchNorm2d(64),  # Thêm BatchNorm
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),  # 64x64x128
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),  # 32x32x256
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1),  # 16x16x512
            nn.BatchNorm2d(512),
            nn.ReLU()
        )

        self.fc_mu = nn.Linear(512*16*16+1, latent_dim)
        self.fc_logvar = nn.Linear(512*16*16+1, latent_dim)

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1),  # 32x32x256
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),  # 64x64x128
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),  # 128x128x64
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1),  # 256x256x3
            nn.Sigmoid()  # Output trong khoảng [0, 1]
        )
        self.latent_to_decoder_input_size = nn.Linear(latent_dim+1, 512*16*16)

    def reparameterize(self, mean, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mean + eps * std

    def encode(self, x, y):
        encoder_output = self.encoder(x)
        x = encoder_output.view(encoder_output.size(0), -1)
        xy = torch.cat([x,y], dim=1)

        mu = self.fc_mu(xy)
        logvar = self.fc_logvar(xy)

        return mu, logvar

    def decode(self, z, y):
        zy = torch.cat([z,y], dim=1)
        z = self.latent_to_decoder_input_size(zy)
        decoder_input = z.view(z.size(0), 512, 16, 16)
        x = self.decoder(decoder_input)

        return x

    def forward(self, x, y):
        mu, logvar = self.encode(x, y)
        z = self.reparameterize(mu, logvar)
        x = self.decode(z, y)

        return x, mu, logvar

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0,max_len).unsqueeze(1).float()
        div_term = torch.exp(torch.arange(0,d_model,2).float()*(-np.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(position*div_term)
        pe[:,1::2] = torch.cos(position*div_term)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self,x):
        L = x.size(1)
        return x + self.pe[:,:L,:]

class ViTransformerDetector(nn.Module):
    def __init__(self, embedder, d_model=128, nhead=8, num_layers=2, dim_feedforward=256, dropout=0.1):
        super().__init__()
        self.embedder = embedder
        self.embedding_dim = embedder.output_dim
        self.projection = nn.Linear(self.embedding_dim,d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead,
                                                   dim_feedforward=dim_feedforward,
                                                   dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Sequential(
            nn.Linear(d_model,128), nn.ReLU(), nn.Dropout(dropout),
            nn.Linear(128,1), nn.Sigmoid()
        )

    def forward(self,x):
        emb = self.embedder(x).view(x.size(0),1,-1)
        emb = self.projection(emb)
        emb = self.positional_encoding(emb)
        h = self.transformer_encoder(emb)
        pooled = h.mean(dim=1)
        return self.fc(pooled).squeeze(1)

class EarlyStopping:
    def __init__(self, patience=5, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float("inf")
        self.early_stop = False

    def step(self, current_loss):
        if current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

    def reset(self):
        self.counter = 0
        self.best_loss = float("inf")
        self.early_stop = False

# %%
def cnn_cvae_loss_fn(x_original, x_recon, mean, logvar, beta=1.0):
    # Reconstruction Loss - so sánh ảnh
    recon_loss = F.mse_loss(x_recon, x_original, reduction='mean')
    # KL Divergence Loss
    kl_loss = -0.5 * torch.sum(1 + logvar - mean.pow(2) - logvar.exp())

    return recon_loss + beta * kl_loss

def train_cnn_ae(model, loader, opt, device):
    model.train()
    total_loss = 0
    for x,y in loader:
        x = x.to(device)
        y = y.unsqueeze(1).to(device)
        recon, mu, logvar = model(x, y)
        loss = cnn_cvae_loss_fn(x, recon, mu, logvar)
        opt.zero_grad()
        loss.backward()
        opt.step()
        total_loss += loss.item() * x.size(0)
    avg_loss = total_loss / len(train_loader.dataset)
    return avg_loss

def train_detector(model, loader, opt, criterion, device):
    model.train()
    total = 0
    for x,y in loader:
        x=x.to(device); y=y.to(device)
        out = model(x)
        loss = criterion(out, y)
        opt.zero_grad()
        loss.backward()
        opt.step()
        total += loss.item()
    return total/len(loader)

# %%
def One_Step_To_Feasible_Action(generator, detector, x_orig, device,
                                previously_generated=None, alpha=1.0,
                                lambda_div=0.1, lr=0.001, steps=50):
    generator.eval()
    detector.eval()
    if previously_generated is None:
        previously_generated = []

    x_orig = x_orig.to(device).unsqueeze(0)
    y_class1 = torch.full((1,1),0.8,device=device)

    with torch.no_grad():
        mean, logvar = generator.encode(x_orig, y_class1)
        z = generator.reparameterize(mean, logvar).detach().clone().requires_grad_(True)

    optimizer_z = torch.optim.Adam([z], lr=lr)

    for step in range(steps):
        optimizer_z.zero_grad()
        x_syn = generator.decode(z, y_class1)
        prob_class1 = detector(x_syn)

        if len(previously_generated) > 0:
            old = torch.stack(previously_generated).to(device)
            diff = x_syn.unsqueeze(1)-old.unsqueeze(0)
            dist_min = diff.norm(p=2,dim=(2,3,4)).min(dim=1).values
            diversity_term = torch.exp(-alpha*dist_min).mean()
        else:
            diversity_term = torch.tensor(0.0, device=device)

        reward = prob_class1.mean() + lambda_div*diversity_term
        reward.backward()
        optimizer_z.step()

    with torch.no_grad():
        x_adv = generator.decode(z, y_class1).detach().cpu()

    return x_adv

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATASET_DIR = "/content/drive/MyDrive/bmad-npz"
# DATASET_NAME = "camelyon16_256"
# DATASET_NAME = "BraTS2021_slice"
DATASET_NAME = "hist_DIY"
DATASET_PATH = f"{DATASET_DIR}/{DATASET_NAME}/{DATASET_NAME}_train.npz"
SYNTHETIC_DIR = f"synthetics/"
os.makedirs(SYNTHETIC_DIR, exist_ok=True)
MODEL_DIR = f"{DATASET_NAME}_models/"
os.makedirs(MODEL_DIR, exist_ok=True)
PATIENTCE = 5
BATCH_SIZE = 100

train_dataset, train_loader, test_dataset, test_loader = load_train_test(
    DATASET_PATH, device=DEVICE, batch_size=BATCH_SIZE, resize=256
)

generator = CnnCVAE(latent_dim=64).to(DEVICE)
embedder = ResNetEmbedder(output_dim=128).to(DEVICE)
detector = ViTransformerDetector(embedder=embedder).to(DEVICE)
early_stopper = EarlyStopping(patience=PATIENTCE)

optimizer_g = torch.optim.Adam(generator.parameters(), lr=1e-4)
optimizer_d = torch.optim.Adam(detector.parameters(), lr=1e-4)
criterion = nn.BCELoss()

synthetic_files = []
num_epochs_generator = 450
num_epochs_detector = 100
num_episodes = 100
num_gen_data = 50
combined_dataset = train_dataset

for ep in range(num_episodes):
    print(f"\n================ EPISODE {ep+1}/{num_episodes} ================")
    total_class0, total_class1 = count_classes(combined_dataset)

    # 2️⃣ Print
    print(f"[Episode {ep+1}] Class count → 0: {total_class0}, 1: {total_class1}")

    # 3️⃣ Auto-stop if balanced
    if total_class1 >= total_class0:
        print("Dataset is now balanced. Stopping synthetic generation.")
        break

    # TRAIN GENERATOR
    early_stopper.reset()
    for epoch in range(num_epochs_generator):
        loss_g = train_cnn_ae(generator, train_loader, optimizer_g, DEVICE)
        print(f"[GENERATOR] Epoch {epoch+1}/{num_epochs_generator}, Loss={loss_g:.4f}")
        early_stopper.step(loss_g)
        if early_stopper.early_stop:
            print(f"[GENERATOR] Early stopping at epoch {epoch+1}")
            break

    torch.save(generator.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_generator.pth")

    # 4️⃣ Train detector
    early_stopper.reset()
    for epoch in range(num_epochs_detector):
        loss_d = train_detector(detector, train_loader, optimizer_d, criterion, DEVICE)
        print(f"[DETECTOR] Epoch {epoch+1}/{num_epochs_detector}, Loss={loss_d:.4f}")
        early_stopper.step(loss_d)
        if early_stopper.early_stop:
            print(f"[DETECTOR] Early stopping at epoch {epoch+1}")
            break

    torch.save(detector.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_detector.pth")

    # 5️⃣ Generate synthetic samples (class 1)
    synthetic_samples = []
    idx_class1 = [i for i, idx_lbl in enumerate(train_dataset.indices) if train_dataset.labels[idx_lbl] == 1]

    for _ in range(num_gen_data):
        if not idx_class1:
            break
        rand_idx = np.random.choice(idx_class1)
        x_orig, _ = train_dataset[rand_idx]
        x_adv = One_Step_To_Feasible_Action(generator, detector, x_orig, DEVICE)
        synthetic_samples.append(x_adv.to(DEVICE))

    syn_tensor = torch.cat(synthetic_samples)            # (N,3,H,W)
    syn_tensor_hwc = syn_tensor.permute(0,2,3,1).cpu().numpy()   # (N,H,W,3)  <-- HWC
    syn_labels = np.ones(len(synthetic_samples), dtype=np.float32)

    syn_path = f"{SYNTHETIC_DIR}/syn_ep{ep}.npz"
    np.savez_compressed(syn_path, images=syn_tensor_hwc, labels=syn_labels)
    synthetic_files.append(syn_path)

    print(f"[EP {ep}] Generated synthetic saved:", syn_path)

    synthetic_subsets = []
    for f in synthetic_files:
        synthetic_subsets.append(SyntheticDataset(f, DEVICE))

    synthetic_full = ConcatDataset(synthetic_subsets)
    combined_dataset = ConcatDataset([train_dataset, synthetic_full])

    train_loader = DataLoader(combined_dataset, batch_size=BATCH_SIZE, shuffle=True)
    print(f"[EP {ep}] Train dataset expanded: now {len(combined_dataset)} samples")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 180MB/s]
# ================ EPISODE 1/100 ================
# [Episode 1] Class count → 0: 790, 1: 234
# [GENERATOR] Epoch 1/450, Loss=8182.3723
# [GENERATOR] Epoch 2/450, Loss=2145.2377
# [GENERATOR] Epoch 3/450, Loss=900.4908
# [GENERATOR] Epoch 4/450, Loss=416.8712
# [GENERATOR] Epoch 5/450, Loss=210.6795
# [GENERATOR] Epoch 6/450, Loss=119.5291
# [GENERATOR] Epoch 7/450, Loss=69.8275
# [GENERATOR] Epoch 8/450, Loss=50.9927
# [GENERATOR] Epoch 9/450, Loss=34.7532
# [GENERATOR] Epoch 10/450, Loss=30.6600
# [GENERATOR] Epoch 11/450, Loss=26.5408
# [GENERATOR] Epoch 12/450, Loss=27.0203
# [GENERATOR] Epoch 13/450, Loss=28.7666
# [GENERATOR] Epoch 14/450, Loss=27.5221
# [GENERATOR] Epoch 15/450, Loss=26.5910
# [GENERATOR] Epoch 16/450, Loss=27.5894
# [GENERATOR] Early stopping at epoch 16
# [DETECTOR] Epoch 1/100, Loss=0.5258
# [DETECTOR] Epoch 2/100, Loss=0.2714
# [DETECTOR] Epoch 3/100, Loss=0.1556
# [DETECTOR] Epoch 4/100, Loss=0.1250
# [DETECTOR] Epoch 5/100, Loss=0.0719
# [DETECTOR] Epoch 6/100, Loss=0.0576
# [DETECTOR] Epoch 7/100, Loss=0.0836
# [DETECTOR] Epoch 8/100, Loss=0.0567
# [DETECTOR] Epoch 9/100, Loss=0.0319
# [DETECTOR] Epoch 10/100, Loss=0.0220
# [DETECTOR] Epoch 11/100, Loss=0.0228
# [DETECTOR] Epoch 12/100, Loss=0.0366
# [DETECTOR] Epoch 13/100, Loss=0.0314
# [DETECTOR] Epoch 14/100, Loss=0.0336
# [DETECTOR] Epoch 15/100, Loss=0.0264
# [DETECTOR] Early stopping at epoch 15
# [EP 0] Generated synthetic saved: synthetics//syn_ep0.npz
# [EP 0] Train dataset expanded: now 1074 samples
#
# ================ EPISODE 2/100 ================
# [Episode 2] Class count → 0: 790, 1: 284
# [GENERATOR] Epoch 1/450, Loss=58.9021
# [GENERATOR] Epoch 2/450, Loss=31.6989
# [GENERATOR] Epoch 3/450, Loss=27.1341
# [GENERATOR] Epoch 4/450, Loss=25.2299
# [GENERATOR] Epoch 5/450, Loss=30.5248
# [GENERATOR] Epoch 6/450, Loss=19.2031
# [GENERATOR] Epoch 7/450, Loss=14.4651
# [GENERATOR] Epoch 8/450, Loss=11.5643
# [GENERATOR] Epoch 9/450, Loss=12.2542
# [GENERATOR] Epoch 10/450, Loss=11.5325
# [GENERATOR] Epoch 11/450, Loss=19.8673
# [GENERATOR] Epoch 12/450, Loss=18.4905
# [GENERATOR] Epoch 13/450, Loss=16.2713
# [GENERATOR] Epoch 14/450, Loss=13.1524
# [GENERATOR] Epoch 15/450, Loss=13.8550
# [GENERATOR] Early stopping at epoch 15
# [DETECTOR] Epoch 1/100, Loss=0.0431
# [DETECTOR] Epoch 2/100, Loss=0.0189
# [DETECTOR] Epoch 3/100, Loss=0.0114
# [DETECTOR] Epoch 4/100, Loss=0.0168
# [DETECTOR] Epoch 5/100, Loss=0.0109
# [DETECTOR] Epoch 6/100, Loss=0.0118
# [DETECTOR] Epoch 7/100, Loss=0.0116
# [DETECTOR] Epoch 8/100, Loss=0.0053
# [DETECTOR] Epoch 9/100, Loss=0.0039
# [DETECTOR] Epoch 10/100, Loss=0.0035
# [DETECTOR] Epoch 11/100, Loss=0.0031
# [DETECTOR] Epoch 12/100, Loss=0.0028
# [DETECTOR] Epoch 13/100, Loss=0.0025
# [DETECTOR] Epoch 14/100, Loss=0.0024
# [DETECTOR] Epoch 15/100, Loss=0.0022
# [DETECTOR] Epoch 16/100, Loss=0.0020
# [DETECTOR] Epoch 17/100, Loss=0.0018
# [DETECTOR] Epoch 18/100, Loss=0.0017
# [DETECTOR] Epoch 19/100, Loss=0.0016
# [DETECTOR] Epoch 20/100, Loss=0.0015
# [DETECTOR] Epoch 21/100, Loss=0.0014
# [DETECTOR] Epoch 22/100, Loss=0.0013
# [DETECTOR] Epoch 23/100, Loss=0.0012
# [DETECTOR] Epoch 24/100, Loss=0.0012
# [DETECTOR] Epoch 25/100, Loss=0.0011
# [DETECTOR] Epoch 26/100, Loss=0.0011
# [DETECTOR] Epoch 27/100, Loss=0.0010
# [DETECTOR] Epoch 28/100, Loss=0.0009
# [DETECTOR] Epoch 29/100, Loss=0.0009
# [DETECTOR] Epoch 30/100, Loss=0.0008
# [DETECTOR] Epoch 31/100, Loss=0.0008
# [DETECTOR] Epoch 32/100, Loss=0.0008
# [DETECTOR] Epoch 33/100, Loss=0.0007
# [DETECTOR] Epoch 34/100, Loss=0.0007
# [DETECTOR] Epoch 35/100, Loss=0.0007
# [DETECTOR] Epoch 36/100, Loss=0.0007
# [DETECTOR] Epoch 37/100, Loss=0.0006
# [DETECTOR] Epoch 38/100, Loss=0.0006
# [DETECTOR] Epoch 39/100, Loss=0.0006
# [DETECTOR] Epoch 40/100, Loss=0.0005
# [DETECTOR] Epoch 41/100, Loss=0.0005
# [DETECTOR] Epoch 42/100, Loss=0.0005
# [DETECTOR] Epoch 43/100, Loss=0.0005
# [DETECTOR] Epoch 44/100, Loss=0.0005
# [DETECTOR] Epoch 45/100, Loss=0.0005
# [DETECTOR] Epoch 46/100, Loss=0.0004
# [DETECTOR] Epoch 47/100, Loss=0.0004
# [DETECTOR] Epoch 48/100, Loss=0.0004
# [DETECTOR] Early stopping at epoch 48
# [EP 1] Generated synthetic saved: synthetics//syn_ep1.npz
# [EP 1] Train dataset expanded: now 1124 samples
#
# ================ EPISODE 3/100 ================
# [Episode 3] Class count → 0: 790, 1: 334
# [GENERATOR] Epoch 1/450, Loss=70.3149
# [GENERATOR] Epoch 2/450, Loss=174.4999
# [GENERATOR] Epoch 3/450, Loss=968.0996
# [GENERATOR] Epoch 4/450, Loss=475.9427
# [GENERATOR] Epoch 5/450, Loss=176.6844
# [GENERATOR] Epoch 6/450, Loss=76.2916
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0005
# [DETECTOR] Epoch 2/100, Loss=0.0004
# [DETECTOR] Epoch 3/100, Loss=0.0004
# [DETECTOR] Epoch 4/100, Loss=0.0004
# [DETECTOR] Epoch 5/100, Loss=0.0004
# [DETECTOR] Epoch 6/100, Loss=0.0003
# [DETECTOR] Epoch 7/100, Loss=0.0003
# [DETECTOR] Epoch 8/100, Loss=0.0003
# [DETECTOR] Early stopping at epoch 8
# [EP 2] Generated synthetic saved: synthetics//syn_ep2.npz
# [EP 2] Train dataset expanded: now 1174 samples
#
# ================ EPISODE 4/100 ================
# [Episode 4] Class count → 0: 790, 1: 384
# [GENERATOR] Epoch 1/450, Loss=36.4431
# [GENERATOR] Epoch 2/450, Loss=24.3269
# [GENERATOR] Epoch 3/450, Loss=15.5784
# [GENERATOR] Epoch 4/450, Loss=9.2806
# [GENERATOR] Epoch 5/450, Loss=8.4842
# [GENERATOR] Epoch 6/450, Loss=7.8413
# [GENERATOR] Epoch 7/450, Loss=9.1739
# [GENERATOR] Epoch 8/450, Loss=9.3052
# [GENERATOR] Epoch 9/450, Loss=6.3264
# [GENERATOR] Epoch 10/450, Loss=5.4956
# [GENERATOR] Epoch 11/450, Loss=5.5247
# [GENERATOR] Epoch 12/450, Loss=8.9066
# [GENERATOR] Epoch 13/450, Loss=7.2268
# [GENERATOR] Epoch 14/450, Loss=5.3923
# [GENERATOR] Epoch 15/450, Loss=6.3250
# [GENERATOR] Epoch 16/450, Loss=6.6630
# [GENERATOR] Epoch 17/450, Loss=9.3318
# [GENERATOR] Epoch 18/450, Loss=9.7364
# [GENERATOR] Epoch 19/450, Loss=5.9715
# [GENERATOR] Early stopping at epoch 19
# [DETECTOR] Epoch 1/100, Loss=0.0003
# [DETECTOR] Epoch 2/100, Loss=0.0003
# [DETECTOR] Epoch 3/100, Loss=0.0003
# [DETECTOR] Epoch 4/100, Loss=0.0003
# [DETECTOR] Epoch 5/100, Loss=0.0003
# [DETECTOR] Epoch 6/100, Loss=0.0003
# [DETECTOR] Early stopping at epoch 6
# [EP 3] Generated synthetic saved: synthetics//syn_ep3.npz
# [EP 3] Train dataset expanded: now 1224 samples
#
# ================ EPISODE 5/100 ================
# [Episode 5] Class count → 0: 790, 1: 434
# [GENERATOR] Epoch 1/450, Loss=7.8148
# [GENERATOR] Epoch 2/450, Loss=13.3465
# [GENERATOR] Epoch 3/450, Loss=40.9014
# [GENERATOR] Epoch 4/450, Loss=178.1403
# [GENERATOR] Epoch 5/450, Loss=809.6279
# [GENERATOR] Epoch 6/450, Loss=1326.6282
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0003
# [DETECTOR] Epoch 2/100, Loss=0.0004
# [DETECTOR] Epoch 3/100, Loss=0.0117
# [DETECTOR] Epoch 4/100, Loss=0.0901
# [DETECTOR] Epoch 5/100, Loss=0.1123
# [DETECTOR] Epoch 6/100, Loss=0.1115
# [DETECTOR] Early stopping at epoch 6
# [EP 4] Generated synthetic saved: synthetics//syn_ep4.npz
# [EP 4] Train dataset expanded: now 1274 samples
#
# ================ EPISODE 6/100 ================
# [Episode 6] Class count → 0: 790, 1: 484
# [GENERATOR] Epoch 1/450, Loss=894.5500
# [GENERATOR] Epoch 2/450, Loss=150.2947
# [GENERATOR] Epoch 3/450, Loss=57.2552
# [GENERATOR] Epoch 4/450, Loss=301.0107
# [GENERATOR] Epoch 5/450, Loss=876.9955
# [GENERATOR] Epoch 6/450, Loss=624.1947
# [GENERATOR] Epoch 7/450, Loss=49.7791
# [GENERATOR] Epoch 8/450, Loss=34.9093
# [GENERATOR] Epoch 9/450, Loss=18.5407
# [GENERATOR] Epoch 10/450, Loss=11.3184
# [GENERATOR] Epoch 11/450, Loss=8.0847
# [GENERATOR] Epoch 12/450, Loss=6.5727
# [GENERATOR] Epoch 13/450, Loss=5.2938
# [GENERATOR] Epoch 14/450, Loss=5.3253
# [GENERATOR] Epoch 15/450, Loss=4.7665
# [GENERATOR] Epoch 16/450, Loss=5.8482
# [GENERATOR] Epoch 17/450, Loss=7.0511
# [GENERATOR] Epoch 18/450, Loss=8.1528
# [GENERATOR] Epoch 19/450, Loss=7.3368
# [GENERATOR] Epoch 20/450, Loss=5.8145
# [GENERATOR] Early stopping at epoch 20
# [DETECTOR] Epoch 1/100, Loss=0.0337
# [DETECTOR] Epoch 2/100, Loss=0.0113
# [DETECTOR] Epoch 3/100, Loss=0.0060
# [DETECTOR] Epoch 4/100, Loss=0.0226
# [DETECTOR] Epoch 5/100, Loss=0.0182
# [DETECTOR] Epoch 6/100, Loss=0.0049
# [DETECTOR] Epoch 7/100, Loss=0.0035
# [DETECTOR] Epoch 8/100, Loss=0.0013
# [DETECTOR] Epoch 9/100, Loss=0.0021
# [DETECTOR] Epoch 10/100, Loss=0.0010
# [DETECTOR] Epoch 11/100, Loss=0.0005
# [DETECTOR] Epoch 12/100, Loss=0.0005
# [DETECTOR] Epoch 13/100, Loss=0.0004
# [DETECTOR] Epoch 14/100, Loss=0.0005
# [DETECTOR] Epoch 15/100, Loss=0.0004
# [DETECTOR] Epoch 16/100, Loss=0.0004
# [DETECTOR] Epoch 17/100, Loss=0.0004
# [DETECTOR] Epoch 18/100, Loss=0.0004
# [DETECTOR] Epoch 19/100, Loss=0.0003
# [DETECTOR] Epoch 20/100, Loss=0.0003
# [DETECTOR] Early stopping at epoch 20
# [EP 5] Generated synthetic saved: synthetics//syn_ep5.npz
# [EP 5] Train dataset expanded: now 1324 samples
#
# ================ EPISODE 7/100 ================
# [Episode 7] Class count → 0: 790, 1: 534
# [GENERATOR] Epoch 1/450, Loss=5.1437
# [GENERATOR] Epoch 2/450, Loss=19.9229
# [GENERATOR] Epoch 3/450, Loss=67.3018
# [GENERATOR] Epoch 4/450, Loss=108.1218
# [GENERATOR] Epoch 5/450, Loss=334.6652
# [GENERATOR] Epoch 6/450, Loss=384.4389
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0023
# [DETECTOR] Epoch 2/100, Loss=0.0603
# [DETECTOR] Epoch 3/100, Loss=0.0306
# [DETECTOR] Epoch 4/100, Loss=0.0174
# [DETECTOR] Epoch 5/100, Loss=0.0105
# [DETECTOR] Epoch 6/100, Loss=0.0023
# [DETECTOR] Early stopping at epoch 6
# [EP 6] Generated synthetic saved: synthetics//syn_ep6.npz
# [EP 6] Train dataset expanded: now 1374 samples
#
# ================ EPISODE 8/100 ================
# [Episode 8] Class count → 0: 790, 1: 584
# [GENERATOR] Epoch 1/450, Loss=1162.7318
# [GENERATOR] Epoch 2/450, Loss=366.0204
# [GENERATOR] Epoch 3/450, Loss=121.0170
# [GENERATOR] Epoch 4/450, Loss=35.6446
# [GENERATOR] Epoch 5/450, Loss=15.8813
# [GENERATOR] Epoch 6/450, Loss=10.0146
# [GENERATOR] Epoch 7/450, Loss=7.6262
# [GENERATOR] Epoch 8/450, Loss=5.3782
# [GENERATOR] Epoch 9/450, Loss=4.1683
# [GENERATOR] Epoch 10/450, Loss=3.9409
# [GENERATOR] Epoch 11/450, Loss=3.8594
# [GENERATOR] Epoch 12/450, Loss=3.8161
# [GENERATOR] Epoch 13/450, Loss=3.5121
# [GENERATOR] Epoch 14/450, Loss=3.3805
# [GENERATOR] Epoch 15/450, Loss=3.6537
# [GENERATOR] Epoch 16/450, Loss=3.2809
# [GENERATOR] Epoch 17/450, Loss=3.9477
# [GENERATOR] Epoch 18/450, Loss=3.0283
# [GENERATOR] Epoch 19/450, Loss=2.9156
# [GENERATOR] Epoch 20/450, Loss=3.7722
# [GENERATOR] Epoch 21/450, Loss=3.9190
# [GENERATOR] Epoch 22/450, Loss=4.0842
# [GENERATOR] Epoch 23/450, Loss=11.5223
# [GENERATOR] Epoch 24/450, Loss=14.2625
# [GENERATOR] Early stopping at epoch 24
# [DETECTOR] Epoch 1/100, Loss=0.0007
# [DETECTOR] Epoch 2/100, Loss=0.0010
# [DETECTOR] Epoch 3/100, Loss=0.0005
# [DETECTOR] Epoch 4/100, Loss=0.0004
# [DETECTOR] Epoch 5/100, Loss=0.0004
# [DETECTOR] Epoch 6/100, Loss=0.0004
# [DETECTOR] Epoch 7/100, Loss=0.0004
# [DETECTOR] Epoch 8/100, Loss=0.0003
# [DETECTOR] Epoch 9/100, Loss=0.0003
# [DETECTOR] Epoch 10/100, Loss=0.0003
# [DETECTOR] Epoch 11/100, Loss=0.0003
# [DETECTOR] Early stopping at epoch 11
# [EP 7] Generated synthetic saved: synthetics//syn_ep7.npz
# [EP 7] Train dataset expanded: now 1424 samples
#
# ================ EPISODE 9/100 ================
# [Episode 9] Class count → 0: 790, 1: 634
# [GENERATOR] Epoch 1/450, Loss=7.3042
# [GENERATOR] Epoch 2/450, Loss=16.4149
# [GENERATOR] Epoch 3/450, Loss=40.7524
# [GENERATOR] Epoch 4/450, Loss=511.3179
# [GENERATOR] Epoch 5/450, Loss=537.5852
# [GENERATOR] Epoch 6/450, Loss=1629.1046
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0016
# [DETECTOR] Epoch 2/100, Loss=0.0024
# [DETECTOR] Epoch 3/100, Loss=0.0104
# [DETECTOR] Epoch 4/100, Loss=0.0347
# [DETECTOR] Epoch 5/100, Loss=0.0218
# [DETECTOR] Epoch 6/100, Loss=0.0042
# [DETECTOR] Early stopping at epoch 6
# [EP 8] Generated synthetic saved: synthetics//syn_ep8.npz
# [EP 8] Train dataset expanded: now 1474 samples
#
# ================ EPISODE 10/100 ================
# [Episode 10] Class count → 0: 790, 1: 684
# [GENERATOR] Epoch 1/450, Loss=1430.0153
# [GENERATOR] Epoch 2/450, Loss=278.9066
# [GENERATOR] Epoch 3/450, Loss=63.1443
# [GENERATOR] Epoch 4/450, Loss=20.6203
# [GENERATOR] Epoch 5/450, Loss=10.4577
# [GENERATOR] Epoch 6/450, Loss=6.1878
# [GENERATOR] Epoch 7/450, Loss=4.9039
# [GENERATOR] Epoch 8/450, Loss=4.9028
# [GENERATOR] Epoch 9/450, Loss=3.9982
# [GENERATOR] Epoch 10/450, Loss=3.7562
# [GENERATOR] Epoch 11/450, Loss=3.5771
# [GENERATOR] Epoch 12/450, Loss=2.7899
# [GENERATOR] Epoch 13/450, Loss=2.7253
# [GENERATOR] Epoch 14/450, Loss=2.4247
# [GENERATOR] Epoch 15/450, Loss=2.7406
# [GENERATOR] Epoch 16/450, Loss=2.8883
# [GENERATOR] Epoch 17/450, Loss=2.4884
# [GENERATOR] Epoch 18/450, Loss=2.5696
# [GENERATOR] Epoch 19/450, Loss=2.7186
# [GENERATOR] Early stopping at epoch 19
# [DETECTOR] Epoch 1/100, Loss=0.0006
# [DETECTOR] Epoch 2/100, Loss=0.0004
# [DETECTOR] Epoch 3/100, Loss=0.0004
# [DETECTOR] Epoch 4/100, Loss=0.0003
# [DETECTOR] Epoch 5/100, Loss=0.0003
# [DETECTOR] Epoch 6/100, Loss=0.0003
# [DETECTOR] Epoch 7/100, Loss=0.0003
# [DETECTOR] Epoch 8/100, Loss=0.0003
# [DETECTOR] Epoch 9/100, Loss=0.0003
# [DETECTOR] Early stopping at epoch 9
# [EP 9] Generated synthetic saved: synthetics//syn_ep9.npz
# [EP 9] Train dataset expanded: now 1524 samples
#
# ================ EPISODE 11/100 ================
# [Episode 11] Class count → 0: 790, 1: 734
# [GENERATOR] Epoch 1/450, Loss=2.2481
# [GENERATOR] Epoch 2/450, Loss=5.4075
# [GENERATOR] Epoch 3/450, Loss=5.6701
# [GENERATOR] Epoch 4/450, Loss=9.4240
# [GENERATOR] Epoch 5/450, Loss=116.2352
# [GENERATOR] Epoch 6/450, Loss=530.6663
# [GENERATOR] Early stopping at epoch 6
# [DETECTOR] Epoch 1/100, Loss=0.0003
# [DETECTOR] Epoch 2/100, Loss=0.0003
# [DETECTOR] Epoch 3/100, Loss=0.0003
# [DETECTOR] Epoch 4/100, Loss=0.0002
# [DETECTOR] Epoch 5/100, Loss=0.0002
# [DETECTOR] Epoch 6/100, Loss=0.0002
# [DETECTOR] Early stopping at epoch 6
# [EP 10] Generated synthetic saved: synthetics//syn_ep10.npz
# [EP 10] Train dataset expanded: now 1574 samples
#
# ================ EPISODE 12/100 ================
# [Episode 12] Class count → 0: 790, 1: 784
# [GENERATOR] Epoch 1/450, Loss=118.1810
# [GENERATOR] Epoch 2/450, Loss=35.7595
# [GENERATOR] Epoch 3/450, Loss=11.8261
# [GENERATOR] Epoch 4/450, Loss=5.1567
# [GENERATOR] Epoch 5/450, Loss=3.3883
# [GENERATOR] Epoch 6/450, Loss=2.7432
# [GENERATOR] Epoch 7/450, Loss=2.2779
# [GENERATOR] Epoch 8/450, Loss=2.0306
# [GENERATOR] Epoch 9/450, Loss=2.1170
# [GENERATOR] Epoch 10/450, Loss=1.9180
# [GENERATOR] Epoch 11/450, Loss=1.4782
# [GENERATOR] Epoch 12/450, Loss=1.8734
# [GENERATOR] Epoch 13/450, Loss=2.0974
# [GENERATOR] Epoch 14/450, Loss=1.8955
# [GENERATOR] Epoch 15/450, Loss=1.6131
# [GENERATOR] Epoch 16/450, Loss=1.9366
# [GENERATOR] Early stopping at epoch 16
# [DETECTOR] Epoch 1/100, Loss=0.0002
# [DETECTOR] Epoch 2/100, Loss=0.0002
# [DETECTOR] Epoch 3/100, Loss=0.0002
# [DETECTOR] Epoch 4/100, Loss=0.0002
# [DETECTOR] Epoch 5/100, Loss=0.0002
# [DETECTOR] Epoch 6/100, Loss=0.0002
# [DETECTOR] Early stopping at epoch 6
# [EP 11] Generated synthetic saved: synthetics//syn_ep11.npz
# [EP 11] Train dataset expanded: now 1624 samples
#
# ================ EPISODE 13/100 ================
# [Episode 13] Class count → 0: 790, 1: 834
# Dataset is now balanced. Stopping synthetic generation.

# %%
final_detector = ViTransformerDetector(embedder=embedder).to(DEVICE)
optimizer_final = torch.optim.Adam(final_detector.parameters(), lr=1e-3)
criterion = nn.BCELoss()
num_epochs_final = 100
early_stopper.reset()

for epoch in range(num_epochs_final):
    loss = train_detector(final_detector, train_loader, optimizer_final, criterion, DEVICE)
    print(f"[FINAL DETECTOR] Epoch {epoch+1}/{num_epochs_final}, Loss={loss:.4f}")

    # Check early stopping
    early_stopper.step(loss)

    if early_stopper.early_stop:
        print(f"[FINAL DETECTOR] Early stopping at epoch {epoch+1}")
        break
# Out:
# [FINAL DETECTOR] Epoch 1/100, Loss=0.2475
# [FINAL DETECTOR] Epoch 2/100, Loss=0.1482
# [FINAL DETECTOR] Epoch 3/100, Loss=0.1391
# [FINAL DETECTOR] Epoch 4/100, Loss=0.1161
# [FINAL DETECTOR] Epoch 5/100, Loss=0.0772
# [FINAL DETECTOR] Epoch 6/100, Loss=0.1444
# [FINAL DETECTOR] Epoch 7/100, Loss=0.1581
# [FINAL DETECTOR] Epoch 8/100, Loss=0.1289
# [FINAL DETECTOR] Epoch 9/100, Loss=0.0750
# [FINAL DETECTOR] Epoch 10/100, Loss=0.0479
# [FINAL DETECTOR] Epoch 11/100, Loss=0.0739
# [FINAL DETECTOR] Epoch 12/100, Loss=0.0487
# [FINAL DETECTOR] Epoch 13/100, Loss=0.0836
# [FINAL DETECTOR] Epoch 14/100, Loss=0.1100
# [FINAL DETECTOR] Epoch 15/100, Loss=0.0822
# [FINAL DETECTOR] Early stopping at epoch 15

# %%
evaluate_model(final_detector, test_loader, DEVICE, threshold=0.3)

# Save final detector
torch.save(final_detector.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_detector_final.pth")
print(f"Final detector saved to {MODEL_DIR}/{DATASET_NAME}_detector_final.pth")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.93      0.98      0.95      1184
#      Class 1       0.91      0.75      0.82       352
#
#     accuracy                           0.93      1536
#    macro avg       0.92      0.87      0.89      1536
# weighted avg       0.92      0.93      0.92      1536
#
# AUC-ROC: 0.8482
# Final detector saved to hist_DIY_models//hist_DIY_detector_final.pth

# %%
import shutil

synthetics_folder = "/content/synthetics"
synthetics_zip = f"{DATASET_NAME}_synthetics"

shutil.make_archive(synthetics_zip, 'zip', synthetics_folder)
# Out:
# '/content/hist_DIY_synthetics.zip'

# %%
import shutil

models_folder = f"/content/{DATASET_NAME}_models"
models_zip = f"{DATASET_NAME}_models"

shutil.make_archive(models_zip, 'zip', models_folder)
# Out:
# '/content/hist_DIY_models.zip'

# %%
f
# Out:
# 'synthetics//syn_ep11.npz'

# %%
import matplotlib.pyplot as plt
from torchvision import transforms
from torch.utils.data import TensorDataset

def preview_images(loader, model=None, device='cpu', num_images=5):
    for images, labels in loader:
        images = images[:num_images]
        labels = labels[:num_images]

        if model is None:
            # Chỉ hiển thị ảnh
            imgs_np = images.cpu().numpy()
            labels_np = labels.cpu().numpy()
            imgs_np = np.clip(imgs_np, 0, 1)
            n = imgs_np.shape[0]
            fig, axes = plt.subplots(1, n, figsize=(3*n, 3))
            if n == 1:
                axes = [axes]
            for j in range(n):
                label = int(labels_np[j])
                axes[j].imshow(imgs_np[j].transpose(1, 2, 0))
                axes[j].set_title(f'[{label}] Image {j}')
                axes[j].axis('off')
            plt.tight_layout()
            plt.show()
        else:
            # Hiển thị Original vs Reconstructed
            model.eval()
            with torch.no_grad():
                images = images.to(device)
                labels = labels.to(device)
                reconstructed, _, _ = model(images, labels.unsqueeze(1))

            orig = images.cpu().numpy()
            recon = reconstructed.cpu().numpy()
            labels_np = labels.cpu().numpy()
            orig = np.clip(orig, 0, 1)
            recon = np.clip(recon, 0, 1)

            n = orig.shape[0]
            fig, axes = plt.subplots(2, n, figsize=(4*n, 8))
            if n == 1:
                axes = axes.reshape(2, 1)

            for j in range(n):
                label = int(labels_np[j])
                axes[0, j].imshow(orig[j].transpose(1, 2, 0))
                axes[0, j].set_title(f'[{label}] Org-{j}')
                axes[0, j].axis('off')

                axes[1, j].imshow(recon[j].transpose(1, 2, 0))
                axes[1, j].set_title(f'[{label}] Recon-{j}')
                axes[1, j].axis('off')
            plt.tight_layout()
            plt.show()

        break  # chỉ lấy 1 batch

def load_data(data, batch_num=64, is_shuffle=True):
    images = data['images']  # shape: (N, H, W, C)
    labels = data['labels']

    # Define transform
    transform = transforms.Compose([
        transforms.ToPILImage(),            # Chuyển numpy array -> PIL Image
        transforms.Resize((256, 256)),      # Resize về 256x256
        transforms.ToTensor()               # Chuyển PIL Image -> Tensor [0,1]
    ])

    # Áp dụng transform cho từng ảnh
    X = torch.stack([transform(img) for img in images])

    # Chuyển labels sang tensor
    y = torch.tensor(labels, dtype=torch.float32)

    # Tạo dataset & dataloader
    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=batch_num, shuffle=is_shuffle)

    return loader

# %%
# data_ep0 = np.load("/content/synthetics/syn_ep0.npz", allow_pickle=True)
syn_data = np.load("/content/synthetics/syn_ep9.npz")
syn_loader = load_data(syn_data)

# %%
preview_images(syn_loader)

# %%
t_data = np.load(f"{DATASET_DIR}/{DATASET_NAME}/{DATASET_NAME}_valid.npz", allow_pickle=True)
t_loader = load_data(t_data)

# %%
preview_images(t_loader)
