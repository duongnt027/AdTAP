# %%
import os
import numpy as np
import torch
import random
import math
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, ConcatDataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score
from torchvision import models
import torch.optim as optim

# %%
def set_seed(seed=42):
    # Python
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

    # NumPy
    np.random.seed(seed)

    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(11)

# %%
# =========================================================
# ENV
# =========================================================
class LatentSpaceEnv:
    def __init__(self, device="cpu", max_steps=10, target_sim=0.7):
        self.device = device
        self.max_steps = max_steps
        self.target_sim = target_sim

        self.X = None
        self.Y = None

    # ================= DATA =================
    def set_data(self, X, Y):
        self.X = X.to(self.device)
        self.Y = Y.to(self.device)

        self.pos_idx = (self.Y == 1).nonzero(as_tuple=True)[0]
        self.neg_idx = (self.Y == 0).nonzero(as_tuple=True)[0]

        assert len(self.pos_idx) > 0, "No label=1 samples"

    # ================= RESET =================
    def reset(self):
        self.current_idx = self.pos_idx[
            torch.randint(len(self.pos_idx), (1,))
        ].item()

        self.x_orig = self.X[self.current_idx]
        self.x_current = self.x_orig.clone()

        self.step_count = 0
        return self.get_state()

    # ================= STATE =================
    def get_state(self):
        return self.x_current.clone()

    # ================= REWARD =================
    def compute_reward(self, x_prime):
        pos_samples = self.X[self.pos_idx]
        neg_samples = self.X[self.neg_idx]

        mean_pos = torch.mean(torch.norm(x_prime - pos_samples, dim=1))
        mean_neg = torch.mean(torch.norm(x_prime - neg_samples, dim=1))
        class_margin = torch.sigmoid(mean_neg - mean_pos)

        cos_pos = F.cosine_similarity(
            x_prime.unsqueeze(0), pos_samples, dim=1
        )
        max_sim = torch.max(cos_pos)
        diversity_penalty = torch.relu(max_sim - 0.95)

        sim_orig = F.cosine_similarity(x_prime, self.x_orig, dim=0)
        target_reward = torch.exp(
            -((sim_orig - self.target_sim) ** 2) / 0.02
        )

        reward = (
            0.5 * class_margin
            + 0.4 * target_reward
            - 0.6 * diversity_penalty
        )

        return reward  # scalar

    # ================= STEP =================
    def step(self, action):
        self.step_count += 1

        x_prime = self.x_current + action
        reward = self.compute_reward(x_prime)

        self.x_current = x_prime.detach()
        done = self.step_count >= self.max_steps

        return self.get_state(), reward, done


# =========================================================
# ACTOR / CRITIC
# =========================================================
class Actor(nn.Module):
    def __init__(self, latent_dim, hidden=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(latent_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )
        self.mu = nn.Linear(hidden, latent_dim)
        self.logstd = nn.Parameter(torch.zeros(latent_dim))

    def forward(self, x):
        h = self.net(x)
        std = self.logstd.exp()
        return self.mu(h), std


class Critic(nn.Module):
    def __init__(self, latent_dim, hidden=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(latent_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1)
        )

    def forward(self, x):
        return self.net(x).squeeze(-1)


# =========================================================
# ROLLOUT BUFFER
# =========================================================
class RolloutBuffer:
    def __init__(self):
        self.clear()

    def clear(self):
        self.states = []
        self.actions = []
        self.logps = []
        self.rewards = []
        self.values = []
        self.dones = []

    def add(self, s, a, logp, r, v, d):
        self.states.append(s)
        self.actions.append(a)
        self.logps.append(logp)
        self.rewards.append(r)
        self.values.append(v)
        self.dones.append(d)


# =========================================================
# PPO
# =========================================================
class PPO:
    def __init__(
        self,
        actor,
        critic,
        env,
        lr=3e-4,
        gamma=0.99,
        lam=0.95,
        clip_eps=0.2,
        train_epochs=5,
        device="cpu"
    ):
        self.actor = actor.to(device)
        self.critic = critic.to(device)
        self.env = env

        self.gamma = gamma
        self.lam = lam
        self.clip_eps = clip_eps
        self.train_epochs = train_epochs
        self.device = device

        self.opt_actor = optim.Adam(self.actor.parameters(), lr=lr)
        self.opt_critic = optim.Adam(self.critic.parameters(), lr=lr)

        self.buffer = RolloutBuffer()

    # ================= ROLLOUT =================
    def collect_trajectories(self, num_episodes=4):
        self.buffer.clear()
        episode_rewards = []

        for _ in range(num_episodes):
            state = self.env.reset()
            ep_reward = 0.0

            for _ in range(self.env.max_steps):
                state = state.to(self.device)

                mu, std = self.actor(state)
                dist = torch.distributions.Normal(mu, std)

                action = dist.sample()
                logp = dist.log_prob(action).sum(dim=-1)

                value = self.critic(state)

                next_state, reward, done = self.env.step(action)

                self.buffer.add(
                    state.detach(),
                    action.detach(),
                    logp.detach(),
                    reward.detach(),
                    value.detach(),
                    done
                )

                state = next_state
                ep_reward += reward.item()

                if done:
                    break

            episode_rewards.append(ep_reward)

        return {"avg_reward": float(np.mean(episode_rewards))}

    # ================= GAE =================
    def compute_gae(self):
        rewards = self.buffer.rewards
        values = self.buffer.values
        dones = self.buffer.dones

        advantages = []
        returns = []

        gae = 0
        next_value = 0

        for t in reversed(range(len(rewards))):
            mask = 1.0 - float(dones[t])
            delta = rewards[t] + self.gamma * next_value * mask - values[t]
            gae = delta + self.gamma * self.lam * mask * gae

            advantages.insert(0, gae)
            returns.insert(0, gae + values[t])

            next_value = values[t]

        return torch.stack(advantages), torch.stack(returns)

    # ================= UPDATE =================
    def learn(self):
        states = torch.stack(self.buffer.states)
        actions = torch.stack(self.buffer.actions)
        old_logps = torch.stack(self.buffer.logps)

        advantages, returns = self.compute_gae()
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        for _ in range(self.train_epochs):
            mu, std = self.actor(states)
            dist = torch.distributions.Normal(mu, std)
            logps = dist.log_prob(actions).sum(dim=-1)

            ratio = torch.exp(logps - old_logps)

            surr1 = ratio * advantages
            surr2 = torch.clamp(
                ratio, 1 - self.clip_eps, 1 + self.clip_eps
            ) * advantages

            actor_loss = -torch.min(surr1, surr2).mean()

            values = self.critic(states)
            critic_loss = F.mse_loss(values, returns)

            self.opt_actor.zero_grad()
            actor_loss.backward()
            self.opt_actor.step()

            self.opt_critic.zero_grad()
            critic_loss.backward()
            self.opt_critic.step()

        avg_reward = torch.stack(self.buffer.rewards).mean().item()
        return actor_loss.item(), critic_loss.item(), avg_reward

    # ================= INFER =================
    @torch.no_grad()
    def infer(self, z0, steps=None, step_scale=0.1):
        self.actor.eval()

        if steps is None:
            steps = self.env.max_steps

        z = z0.clone().to(self.device)

        for _ in range(steps):
            mu, _ = self.actor(z)
            z = z + step_scale * torch.tanh(mu)

        return z



# =========================================================
# OFFLINE REFINEMENT
# =========================================================
@torch.no_grad()
def refine_latent_offline(actor, x0, steps=8, step_scale=0.1):
    x = x0.clone()
    for _ in range(steps):
        mu, _ = actor(x)
        x = x + step_scale * torch.tanh(mu)
    return x

# %%
class NPZDataset(Dataset):
    def __init__(self, path, indices=None, resize=256, device="cpu"):
        self.data = np.load(path, allow_pickle=True, mmap_mode="r")
        self.images = self.data["images"]
        self.labels = self.data["labels"]

        if indices is None:
            self.indices = np.arange(len(self.labels))
        else:
            self.indices = indices

        self.resize = resize
        self.device = device

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        i = self.indices[idx]
        img = torch.tensor(self.images[i]).float()
        lbl = torch.tensor(self.labels[i]).float()

        img = img.permute(2,0,1)
        if img.max() > 1:
            img = img / 255.

        img = F.interpolate(
            img.unsqueeze(0),
            size=(self.resize, self.resize),
            mode="bilinear",
            align_corners=False
        ).squeeze(0)

        return img.to(self.device), lbl.to(self.device)

class SyntheticDataset(Dataset):
    def __init__(self, path, device):
        self.data = np.load(path, mmap_mode="r")
        self.images = self.data["images"]
        self.labels = self.data["labels"]
        self.device = device

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        img = torch.from_numpy(self.images[idx]).float().permute(2,0,1)
        lbl = torch.tensor(self.labels[idx], dtype=torch.float32)
        return img.to(self.device), lbl.to(self.device)

# %%
def load_train_test(
    path,
    device="cpu",
    batch_size=32,
    resize=256,
    test_size=0.6,
    ratio_0=20/85,
    seed=42
):
    data = np.load(path, mmap_mode="r")
    labels = data["labels"]

    # ---- lọc nhãn ----
    idx_1 = np.where(labels == 1)[0]
    idx_0 = np.where(labels == 0)[0]

    n0 = int(len(idx_0) * ratio_0)
    np.random.seed(seed)
    idx_0 = np.random.choice(idx_0, n0, replace=False)

    indices = np.concatenate([idx_1, idx_0])
    np.random.shuffle(indices)

    # ---- split ----
    if test_size > 0:
        train_idx, test_idx = train_test_split(
            indices,
            test_size=test_size,
            stratify=labels[indices],
            random_state=seed
        )
    else:
        train_idx = indices
        test_idx = []

    train_dataset = NPZDataset(path, train_idx, resize, device)
    test_dataset  = NPZDataset(path, test_idx,  resize, device) if len(test_idx) > 0 else None

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader  = DataLoader(test_dataset, batch_size=batch_size) if test_dataset else None

    return train_dataset, train_loader, test_dataset, test_loader

def count_classes(dataset):
    count0 = 0
    count1 = 0

    for i in range(len(dataset)):
        lbl = dataset[i][1]    # dataset[i] → (image, label)
        lbl = int(lbl.item())  # convert to 0 hoặc 1

        if lbl == 0:
            count0 += 1
        else:
            count1 += 1
    return count0, count1

def evaluate_model(model, loader, device, threshold=0.5):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for x_batch, y_batch in loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            y_pred = model(x_batch).squeeze()
            all_preds.append(y_pred.cpu())
            all_labels.append(y_batch.cpu())

    preds = torch.cat(all_preds).numpy()
    labels = torch.cat(all_labels).numpy()


    binary_pred = (preds > threshold).astype(int)

    print("Classification Report:")
    print(classification_report(labels, binary_pred, labels=[0,1], target_names=["Class 0","Class 1"]))

    if len(set(labels)) > 1:
        auc = roc_auc_score(labels, preds)
        print(f"AUC-ROC: {auc:.4f}")
    else:
        print("AUC-ROC: Undefined (only one class present)")

# %%
class ResNetEmbedder(nn.Module):
    def __init__(self, output_dim=128, pretrained=True):
        super().__init__()
        self.backbone = models.resnet50(pretrained=pretrained)
        self.backbone.fc = nn.Identity()
        self.dim_adjuster = nn.Linear(2048, output_dim)
        self.output_dim = output_dim

    def forward(self, images):
        features = self.backbone(images)
        features = features.squeeze()
        if features.dim() == 1:
            features = features.unsqueeze(0)
        features = self.dim_adjuster(features)
        return features

class CNNAutoEncoder(nn.Module):
    def __init__(self, latent_dim=128):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3,64,4,2,1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.Conv2d(64,128,4,2,1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.Conv2d(128,256,4,2,1), nn.BatchNorm2d(256), nn.ReLU(),
            nn.Conv2d(256,512,4,2,1), nn.BatchNorm2d(512), nn.ReLU()
        )
        self.encoder2latent = nn.Linear(512*16*16+1, latent_dim)
        self.latent2decoder = nn.Linear(latent_dim+1, 512*16*16)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(512,256,4,2,1), nn.BatchNorm2d(256), nn.ReLU(),
            nn.ConvTranspose2d(256,128,4,2,1), nn.BatchNorm2d(128), nn.ReLU(),
            nn.ConvTranspose2d(128,64,4,2,1), nn.BatchNorm2d(64), nn.ReLU(),
            nn.ConvTranspose2d(64,3,4,2,1), nn.Sigmoid()
        )

    def encode(self, x, y):
        h = self.encoder(x)
        flat = h.view(x.size(0), -1)
        xy = torch.cat([flat, y], dim=1)
        z = self.encoder2latent(xy)
        return z

    def decode(self, z, y):
        zy = torch.cat([z, y], dim=1)
        flat = self.latent2decoder(zy)
        h = flat.view(z.size(0),512,16,16)
        x_recon = self.decoder(h)
        return x_recon

    def forward(self, x, y):
        z = self.encode(x, y)
        return self.decode(z, y)

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0,max_len).unsqueeze(1).float()
        div_term = torch.exp(torch.arange(0,d_model,2).float()*(-np.log(10000.0)/d_model))
        pe[:,0::2] = torch.sin(position*div_term)
        pe[:,1::2] = torch.cos(position*div_term)
        self.register_buffer("pe", pe.unsqueeze(0))

    def forward(self,x):
        L = x.size(1)
        return x + self.pe[:,:L,:]

class ViTransformerDetector(nn.Module):
    def __init__(self, embedder, d_model=128, nhead=8, num_layers=2, dim_feedforward=256, dropout=0.1):
        super().__init__()
        self.embedder = embedder
        self.embedding_dim = embedder.output_dim
        self.projection = nn.Linear(self.embedding_dim,d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead,
                                                   dim_feedforward=dim_feedforward,
                                                   dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Sequential(
            nn.Linear(d_model,128), nn.ReLU(), nn.Dropout(dropout),
            nn.Linear(128,1), nn.Sigmoid()
        )

    def forward(self,x):
        emb = self.embedder(x).view(x.size(0),1,-1)
        emb = self.projection(emb)
        emb = self.positional_encoding(emb)
        h = self.transformer_encoder(emb)
        pooled = h.mean(dim=1)
        return self.fc(pooled).squeeze(1)

class EarlyStopping:
    def __init__(self, patience=5, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float("inf")
        self.early_stop = False

    def step(self, current_loss):
        if current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

    def reset(self):
        self.counter = 0
        self.best_loss = float("inf")
        self.early_stop = False

# %%
def train_cnn_ae(model, loader, opt, device):
    model.train()
    total = 0
    for x,y in loader:
        x = x.to(device)
        y = y.unsqueeze(1).to(device)
        recon = model.decode(model.encode(x,y), y)
        loss = torch.mean(torch.abs(x - recon))
        opt.zero_grad()
        loss.backward()
        opt.step()
        total += loss.item()
    return total/len(loader)

def train_detector(model, loader, opt, criterion, device):
    model.train()
    total = 0
    for x,y in loader:
        x=x.to(device); y=y.to(device)
        out = model(x)
        loss = criterion(out, y)
        opt.zero_grad()
        loss.backward()
        opt.step()
        total += loss.item()
    return total/len(loader)

# %%
def One_Step_To_Feasible_Action(generator, detector, x_orig, device,
                                previously_generated=None, alpha=1.0,
                                lambda_div=0.1, lr=0.001, steps=50):
    generator.eval()
    detector.eval()
    if previously_generated is None:
        previously_generated = []

    x_orig = x_orig.to(device).unsqueeze(0)
    y_class1 = torch.full((1,1),0.8,device=device)

    with torch.no_grad():
        z = generator.encode(x_orig, y_class1)
    z = z.clone().detach().requires_grad_(True)

    optimizer_z = torch.optim.Adam([z], lr=lr)

    for step in range(steps):
        optimizer_z.zero_grad()
        x_syn = generator.decode(z, y_class1)
        prob_class1 = detector(x_syn)

        if len(previously_generated) > 0:
            old = torch.stack(previously_generated).to(device)
            diff = x_syn.unsqueeze(1)-old.unsqueeze(0)
            dist_min = diff.norm(p=2,dim=(2,3,4)).min(dim=1).values
            diversity_term = torch.exp(-alpha*dist_min).mean()
        else:
            diversity_term = torch.tensor(0.0, device=device)

        reward = prob_class1.mean() + lambda_div*diversity_term
        reward.backward()
        optimizer_z.step()

    with torch.no_grad():
        x_adv = generator.decode(z, y_class1).detach().cpu()

    return x_adv

def Gen_with_PPO(
    actor,
    generator,
    x_orig,
    device,
    episodes,
    steps=8
):
    actor.eval()
    generator.eval()

    # ===== y_class1 GIỮ NGUYÊN =====
    conf = 0.8 + 0.1 / (1 + math.exp(-0.1 * (episodes - 10)))
    y_class1 = torch.full(
        (1, 1),
        random.uniform(max(conf - 0.02, 0.8), conf),
        device=device
    )

    with torch.no_grad():
        z0 = generator.encode(
            x_orig.unsqueeze(0).to(device),
            y_class1
        )

    # ✅ ĐÚNG TÊN HÀM
    z_adv = refine_latent_offline(
        actor,
        z0.squeeze(0),
        steps=steps
    )

    if not check_valid_variant(z_adv, z0.squeeze(0)):
        return None

    with torch.no_grad():
        x_synthetic = generator.decode(
            z_adv.unsqueeze(0),
            y_class1
        )

    return x_synthetic


def check_valid_variant(x, x_prime, threshold=0.3):
    # Flatten nếu có batch dimension
    if x.dim() > 1:
        x_flat = x.view(x.size(0), -1)
        x_prime_flat = x_prime.view(x_prime.size(0), -1)
        cos_sim = torch.nn.functional.cosine_similarity(x_flat, x_prime_flat, dim=1)
    else:
        cos_sim = torch.nn.functional.cosine_similarity(x, x_prime, dim=0)
    
    cos_dist = 1 - cos_sim
    
    # Trả về boolean value duy nhất
    # Nếu có nhiều samples, kiểm tra xem TẤT CẢ có valid không
    is_valid = (cos_dist < threshold).all()
    
    return is_valid.item()  # Convert tensor to Python bool

def load_z_space(generator, loader, device):
    generator.eval()

    all_z = []
    all_y = []

    with torch.no_grad():
        for x, y in loader:
            x = x.to(device)
            y = y.unsqueeze(1).to(device)

            z = generator.encode(x, y)   # (batch, z_dim)

            all_z.append(z.cpu())
            all_y.append(y.cpu())

    # Ghép toàn bộ batch lại
    all_z = torch.cat(all_z, dim=0)
    all_y = torch.cat(all_y, dim=0)

    return all_z, all_y

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATASET_DIR = "/kaggle/input/anomaly-dataset-npz/npz-dataset/BMAD-AD"
# DATASET_NAME = "RESC"
DATASET_NAME = "OCT2017"
# DATASET_NAME = "hist_DIY"
DATASET_PATH = f"{DATASET_DIR}/{DATASET_NAME}/BMAD-AD_{DATASET_NAME}_train.npz"
SYNTHETIC_DIR = f"synthetics/"
os.makedirs(SYNTHETIC_DIR, exist_ok=True)
MODEL_DIR = f"{DATASET_NAME}_models/"
os.makedirs(MODEL_DIR, exist_ok=True)
PATIENTCE = 5
BATCH_SIZE = 100
LATENT_DIM = 64
REFINE_STEP = 10

train_dataset, train_loader, test_dataset, test_loader = load_train_test(
    DATASET_PATH, device=DEVICE, batch_size=BATCH_SIZE, resize=256
)

# ===== ENV =====
env = LatentSpaceEnv(
    device=DEVICE,
    max_steps=REFINE_STEP
)

# ===== ACTOR / CRITIC =====
actor = Actor(
    latent_dim=LATENT_DIM,
    hidden=256
)

critic = Critic(
    latent_dim=LATENT_DIM,
    hidden=256
)

# ===== PPO =====
ppo = PPO(
    actor=actor,
    critic=critic,
    env=env,
    lr=3e-4,
    gamma=0.99,
    lam=0.95,
    clip_eps=0.2,
    device=DEVICE
)

generator = CNNAutoEncoder(latent_dim=LATENT_DIM).to(DEVICE)
embedder = ResNetEmbedder(output_dim=128).to(DEVICE)
detector = ViTransformerDetector(embedder=embedder).to(DEVICE)
early_stopper = EarlyStopping(patience=PATIENTCE)

optimizer_g = torch.optim.Adam(generator.parameters(), lr=1e-4)
optimizer_d = torch.optim.Adam(detector.parameters(), lr=1e-4)
criterion = nn.BCELoss()

synthetic_files = []
num_epochs_generator = 100
num_epochs_detector = 100
num_episodes = 100
num_steps_ppo = 100
num_gen_data = 100
combined_dataset = train_dataset

for ep in range(num_episodes):
    print(f"\n================ EPISODE {ep+1}/{num_episodes} ================")
    total_class0, total_class1 = count_classes(combined_dataset)

    # 2️⃣ Print
    print(f"[Episode {ep+1}] Class count → 0: {total_class0}, 1: {total_class1}")

    # 3️⃣ Auto-stop if balanced
    if total_class1 >= total_class0:
        print("Dataset is now balanced. Stopping synthetic generation.")
        break

    # TRAIN GENERATOR
    early_stopper.reset()
    for epoch in range(num_epochs_generator):
        loss_g = train_cnn_ae(generator, train_loader, optimizer_g, DEVICE)
        if (epoch + 1) % 10 == 0:
            print(f"[GENERATOR] Epoch {epoch+1}/{num_epochs_generator}, Loss={loss_g:.4f}")
        early_stopper.step(loss_g)
        if early_stopper.early_stop:
            print(f"[GENERATOR] Early stopping at epoch {epoch+1}")
            print(f"[GENERATOR] Epoch {epoch+1}/{num_epochs_generator}, Loss={loss_g:.4f}")
            break

    torch.save(generator.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_generator.pth")

    # 4️⃣ Train detector
    
    # early_stopper.reset()
    # for epoch in range(num_epochs_detector):
    #     loss_d = train_detector(detector, train_loader, optimizer_d, criterion, DEVICE)
    #     if (epoch + 1) % 10 == 0:
    #         print(f"[DETECTOR] Epoch {epoch+1}/{num_epochs_detector}, Loss={loss_d:.4f}")
    #     early_stopper.step(loss_d)
    #     if early_stopper.early_stop:
    #         print(f"[DETECTOR] Early stopping at epoch {epoch+1}")
    #         print(f"[DETECTOR] Epoch {epoch+1}/{num_epochs_detector}, Loss={loss_d:.4f}")
    #         break

    # torch.save(detector.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_detector.pth")


    # 5️⃣ Generate synthetic samples (class 1)
    synthetic_samples = []
    idx_class1 = [i for i, idx_lbl in enumerate(train_dataset.indices) if train_dataset.labels[idx_lbl] == 1]

    ppo_gen_count = 0
    for _ in range(num_gen_data):
        if not idx_class1:
            break
        rand_idx = np.random.choice(idx_class1)
        x_orig, _ = train_dataset[rand_idx]
        x_adv = None
        if ep != 0:
            x_adv = Gen_with_PPO(actor, generator, x_orig, DEVICE, ep+1, REFINE_STEP)
        if x_adv is None:
            x_adv = One_Step_To_Feasible_Action(generator, detector, x_orig, DEVICE)
        else:
            ppo_gen_count += 1
        synthetic_samples.append(x_adv.to(DEVICE))

    ppo_gen_rate  = (ppo_gen_count / num_gen_data) * 100
    print(f"{ppo_gen_rate:.2f}% of data generated by PPO strategy")
    
    syn_tensor = torch.cat(synthetic_samples)            # (N,3,H,W)
    syn_tensor_hwc = syn_tensor.permute(0,2,3,1).cpu().numpy()   # (N,H,W,3)  <-- HWC
    syn_labels = np.ones(len(synthetic_samples), dtype=np.float32)

    syn_path = f"{SYNTHETIC_DIR}/syn_ep{ep+1}.npz"
    np.savez_compressed(syn_path, images=syn_tensor_hwc, labels=syn_labels)
    synthetic_files.append(syn_path)

    print(f"[EP {ep+1}] Generated synthetic saved:", syn_path)

    synthetic_subsets = []
    for f in synthetic_files:
        synthetic_subsets.append(SyntheticDataset(f, DEVICE))

    synthetic_full = ConcatDataset(synthetic_subsets)
    combined_dataset = ConcatDataset([train_dataset, synthetic_full])

    train_loader = DataLoader(combined_dataset, batch_size=BATCH_SIZE, shuffle=True)

    Z_ppo, Y_ppo = load_z_space(generator, train_loader, DEVICE)
    # env.set_models(generator, detector)
    env.set_data(Z_ppo, Y_ppo)
    # ===== TRAIN PPO =====
    early_stopper.reset()
    
    for step in range(num_steps_ppo):
    
        rollout_stats = ppo.collect_trajectories(
            num_episodes=4   # ✅ FIX CỨNG, KHÔNG DÙNG env.batch_size
        )
    
        a_loss, c_loss, avg_reward = ppo.learn()
    
        if (step + 1) % 1 == 0:
            print(
                f"Step {step:03d} | "
                f"Actor Loss = {a_loss:.4f}, "
                f"Critic Loss = {c_loss:.4f}, "
                f"AvgReward = {avg_reward:.4f}"
            )
    
        early_stopper.step(-avg_reward)
        if early_stopper.early_stop:
            print(f"[PPO] Early stopping at step {step+1}")
            print(
                f"Step {step:03d} | "
                f"Actor Loss = {a_loss:.4f}, "
                f"Critic Loss = {c_loss:.4f}, "
                f"AvgReward = {avg_reward:.4f}"
            )
            break

    
    print(f"[EP {ep+1}] Train dataset expanded: now {len(combined_dataset)} samples")
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ================ EPISODE 1/100 ================
# [Episode 1] Class count → 0: 2000, 1: 240
# [GENERATOR] Epoch 10/100, Loss=0.0671
# [GENERATOR] Epoch 20/100, Loss=0.0498
# [GENERATOR] Epoch 30/100, Loss=0.0447
# [GENERATOR] Epoch 40/100, Loss=0.0420
# [GENERATOR] Epoch 50/100, Loss=0.0408
# [GENERATOR] Epoch 60/100, Loss=0.0393
# [GENERATOR] Epoch 70/100, Loss=0.0384
# [GENERATOR] Epoch 80/100, Loss=0.0376
# [GENERATOR] Early stopping at epoch 89
# [GENERATOR] Epoch 89/100, Loss=0.0374
# 0.00% of data generated by PPO strategy
# [EP 1] Generated synthetic saved: synthetics//syn_ep1.npz
# Step 000 | Actor Loss = -0.1238, Critic Loss = 0.2849, AvgReward = 0.4483
# Step 001 | Actor Loss = -0.1404, Critic Loss = 0.4001, AvgReward = 0.4105
# Step 002 | Actor Loss = -0.1300, Critic Loss = 0.5028, AvgReward = 0.3466
# Step 003 | Actor Loss = -0.1370, Critic Loss = 0.3304, AvgReward = 0.3022
# Step 004 | Actor Loss = -0.1182, Critic Loss = 0.3374, AvgReward = 0.3468
# Step 005 | Actor Loss = -0.1660, Critic Loss = 0.2748, AvgReward = 0.4180
# [PPO] Early stopping at step 6
# Step 005 | Actor Loss = -0.1660, Critic Loss = 0.2748, AvgReward = 0.4180
# [EP 1] Train dataset expanded: now 2340 samples
#
# ================ EPISODE 2/100 ================
# [Episode 2] Class count → 0: 2000, 1: 340
# [GENERATOR] Epoch 10/100, Loss=0.0353
# [GENERATOR] Epoch 20/100, Loss=0.0353
# [GENERATOR] Early stopping at epoch 27
# [GENERATOR] Epoch 27/100, Loss=0.0352
# 100.00% of data generated by PPO strategy
# [EP 2] Generated synthetic saved: synthetics//syn_ep2.npz
# Step 000 | Actor Loss = -0.1501, Critic Loss = 0.3603, AvgReward = 0.3948
# Step 001 | Actor Loss = -0.1251, Critic Loss = 0.6242, AvgReward = 0.3729
# Step 002 | Actor Loss = -0.1692, Critic Loss = 0.2292, AvgReward = 0.4376
# Step 003 | Actor Loss = -0.1494, Critic Loss = 0.1928, AvgReward = 0.3741
# Step 004 | Actor Loss = -0.1015, Critic Loss = 0.5502, AvgReward = 0.5096
# Step 005 | Actor Loss = -0.1579, Critic Loss = 0.4575, AvgReward = 0.4950
# Step 006 | Actor Loss = -0.1224, Critic Loss = 0.2465, AvgReward = 0.4808
# Step 007 | Actor Loss = -0.1641, Critic Loss = 0.3676, AvgReward = 0.2915
# Step 008 | Actor Loss = -0.1709, Critic Loss = 0.3767, AvgReward = 0.4593
# Step 009 | Actor Loss = -0.1052, Critic Loss = 1.0969, AvgReward = 0.3253
# [PPO] Early stopping at step 10
# Step 009 | Actor Loss = -0.1052, Critic Loss = 1.0969, AvgReward = 0.3253
# [EP 2] Train dataset expanded: now 2440 samples
#
# ================ EPISODE 3/100 ================
# [Episode 3] Class count → 0: 2000, 1: 440
# [GENERATOR] Early stopping at epoch 8
# [GENERATOR] Epoch 8/100, Loss=0.0335
# 100.00% of data generated by PPO strategy
# [EP 3] Generated synthetic saved: synthetics//syn_ep3.npz
# Step 000 | Actor Loss = -0.1239, Critic Loss = 0.8001, AvgReward = 0.4713
# Step 001 | Actor Loss = -0.1445, Critic Loss = 0.6833, AvgReward = 0.4284
# Step 002 | Actor Loss = -0.1248, Critic Loss = 1.1648, AvgReward = 0.3490
# Step 003 | Actor Loss = -0.1218, Critic Loss = 0.6929, AvgReward = 0.5236
# Step 004 | Actor Loss = -0.1351, Critic Loss = 0.3626, AvgReward = 0.4589
# Step 005 | Actor Loss = -0.1346, Critic Loss = 0.4481, AvgReward = 0.5135
# Step 006 | Actor Loss = -0.1358, Critic Loss = 0.3651, AvgReward = 0.5778
# Step 007 | Actor Loss = -0.1280, Critic Loss = 0.5406, AvgReward = 0.6042
# Step 008 | Actor Loss = -0.1371, Critic Loss = 0.2477, AvgReward = 0.5486
# Step 009 | Actor Loss = -0.1530, Critic Loss = 0.3561, AvgReward = 0.6209
# Step 010 | Actor Loss = -0.1743, Critic Loss = 0.7989, AvgReward = 0.4922
# Step 011 | Actor Loss = -0.0780, Critic Loss = 0.2647, AvgReward = 0.5687
# Step 012 | Actor Loss = -0.1131, Critic Loss = 0.1971, AvgReward = 0.4495
# Step 013 | Actor Loss = -0.1159, Critic Loss = 0.3515, AvgReward = 0.5259
# Step 014 | Actor Loss = -0.1149, Critic Loss = 0.4879, AvgReward = 0.5703
# [PPO] Early stopping at step 15
# Step 014 | Actor Loss = -0.1149, Critic Loss = 0.4879, AvgReward = 0.5703
# [EP 3] Train dataset expanded: now 2540 samples
#
# ================ EPISODE 4/100 ================
# [Episode 4] Class count → 0: 2000, 1: 540
# [GENERATOR] Early stopping at epoch 6
# [GENERATOR] Epoch 6/100, Loss=0.0321
# 100.00% of data generated by PPO strategy
# [EP 4] Generated synthetic saved: synthetics//syn_ep4.npz
# Step 000 | Actor Loss = -0.1147, Critic Loss = 0.4602, AvgReward = 0.5675
# Step 001 | Actor Loss = -0.1529, Critic Loss = 0.5522, AvgReward = 0.5193
# Step 002 | Actor Loss = -0.1186, Critic Loss = 0.9196, AvgReward = 0.6236
# Step 003 | Actor Loss = -0.0675, Critic Loss = 0.1737, AvgReward = 0.6034
# Step 004 | Actor Loss = 0.1243, Critic Loss = 0.2282, AvgReward = 0.5373
# Step 005 | Actor Loss = -0.0844, Critic Loss = 0.2976, AvgReward = 0.5601
# Step 006 | Actor Loss = -0.1023, Critic Loss = 0.1422, AvgReward = 0.6229
# Step 007 | Actor Loss = -0.0949, Critic Loss = 0.5183, AvgReward = 0.4695
# [PPO] Early stopping at step 8
# Step 007 | Actor Loss = -0.0949, Critic Loss = 0.5183, AvgReward = 0.4695
# [EP 4] Train dataset expanded: now 2640 samples
#
# ================ EPISODE 5/100 ================
# [Episode 5] Class count → 0: 2000, 1: 640
# [GENERATOR] Epoch 10/100, Loss=0.0309
# [GENERATOR] Early stopping at epoch 13
# [GENERATOR] Epoch 13/100, Loss=0.0315
# 100.00% of data generated by PPO strategy
# [EP 5] Generated synthetic saved: synthetics//syn_ep5.npz
# Step 000 | Actor Loss = -0.1072, Critic Loss = 0.6378, AvgReward = 0.5741
# Step 001 | Actor Loss = -0.0804, Critic Loss = 0.2308, AvgReward = 0.5274
# Step 002 | Actor Loss = -0.1604, Critic Loss = 0.3867, AvgReward = 0.3847
# Step 003 | Actor Loss = -0.0870, Critic Loss = 0.2026, AvgReward = 0.6039
# Step 004 | Actor Loss = -0.0556, Critic Loss = 0.2546, AvgReward = 0.5785
# Step 005 | Actor Loss = -0.1323, Critic Loss = 0.3077, AvgReward = 0.5727
# Step 006 | Actor Loss = 0.0123, Critic Loss = 0.6718, AvgReward = 0.4218
# Step 007 | Actor Loss = -0.1006, Critic Loss = 1.0015, AvgReward = 0.4844
# Step 008 | Actor Loss = -0.0819, Critic Loss = 0.4068, AvgReward = 0.4847
# [PPO] Early stopping at step 9
# Step 008 | Actor Loss = -0.0819, Critic Loss = 0.4068, AvgReward = 0.4847
# [EP 5] Train dataset expanded: now 2740 samples
#
# ================ EPISODE 6/100 ================
# [Episode 6] Class count → 0: 2000, 1: 740
# [GENERATOR] Early stopping at epoch 8
# [GENERATOR] Epoch 8/100, Loss=0.0301
# 100.00% of data generated by PPO strategy
# [EP 6] Generated synthetic saved: synthetics//syn_ep6.npz
# Step 000 | Actor Loss = -0.0475, Critic Loss = 0.4732, AvgReward = 0.5661
# Step 001 | Actor Loss = 0.0647, Critic Loss = 0.2590, AvgReward = 0.5246
# Step 002 | Actor Loss = -0.0175, Critic Loss = 0.4189, AvgReward = 0.5455
# Step 003 | Actor Loss = -0.0695, Critic Loss = 0.4722, AvgReward = 0.5500
# Step 004 | Actor Loss = -0.0088, Critic Loss = 0.2132, AvgReward = 0.6009
# Step 005 | Actor Loss = -0.0600, Critic Loss = 0.6801, AvgReward = 0.5696
# Step 006 | Actor Loss = -0.0975, Critic Loss = 0.8499, AvgReward = 0.5281
# Step 007 | Actor Loss = -0.1062, Critic Loss = 1.3664, AvgReward = 0.6210
# Step 008 | Actor Loss = -0.0609, Critic Loss = 0.6508, AvgReward = 0.6274
# Step 009 | Actor Loss = -0.0611, Critic Loss = 0.3407, AvgReward = 0.4407
# Step 010 | Actor Loss = -0.1043, Critic Loss = 0.0776, AvgReward = 0.6068
# Step 011 | Actor Loss = 0.0910, Critic Loss = 0.1934, AvgReward = 0.5377
# Step 012 | Actor Loss = 0.0226, Critic Loss = 0.1564, AvgReward = 0.5023
# Step 013 | Actor Loss = 0.0979, Critic Loss = 0.2514, AvgReward = 0.5861
# [PPO] Early stopping at step 14
# Step 013 | Actor Loss = 0.0979, Critic Loss = 0.2514, AvgReward = 0.5861
# [EP 6] Train dataset expanded: now 2840 samples
#
# ================ EPISODE 7/100 ================
# [Episode 7] Class count → 0: 2000, 1: 840
# [GENERATOR] Epoch 10/100, Loss=0.0290
# [GENERATOR] Early stopping at epoch 14
# [GENERATOR] Epoch 14/100, Loss=0.0290
# 100.00% of data generated by PPO strategy
# [EP 7] Generated synthetic saved: synthetics//syn_ep7.npz
# Step 000 | Actor Loss = -0.1457, Critic Loss = 0.8295, AvgReward = 0.5807
# Step 001 | Actor Loss = 0.0134, Critic Loss = 0.3382, AvgReward = 0.5040
# Step 002 | Actor Loss = 0.0263, Critic Loss = 0.1315, AvgReward = 0.5115
# Step 003 | Actor Loss = -0.1263, Critic Loss = 0.3129, AvgReward = 0.5339
# Step 004 | Actor Loss = -0.0823, Critic Loss = 0.2135, AvgReward = 0.6146
# Step 005 | Actor Loss = -0.0543, Critic Loss = 0.1014, AvgReward = 0.5135
# Step 006 | Actor Loss = 0.0253, Critic Loss = 0.3437, AvgReward = 0.5954
# Step 007 | Actor Loss = 0.0982, Critic Loss = 0.1097, AvgReward = 0.5917
# Step 008 | Actor Loss = 0.0234, Critic Loss = 0.2955, AvgReward = 0.5580
# Step 009 | Actor Loss = -0.0268, Critic Loss = 0.2237, AvgReward = 0.6569
# Step 010 | Actor Loss = 0.1947, Critic Loss = 0.2849, AvgReward = 0.4977
# Step 011 | Actor Loss = -0.0742, Critic Loss = 0.1311, AvgReward = 0.6633
# Step 012 | Actor Loss = 0.0863, Critic Loss = 0.2750, AvgReward = 0.5997
# Step 013 | Actor Loss = 0.2136, Critic Loss = 0.4657, AvgReward = 0.6061
# Step 014 | Actor Loss = 0.0481, Critic Loss = 0.3563, AvgReward = 0.6306
# Step 015 | Actor Loss = 0.0216, Critic Loss = 0.1780, AvgReward = 0.5137
# Step 016 | Actor Loss = -0.1168, Critic Loss = 0.1979, AvgReward = 0.6379
# [PPO] Early stopping at step 17
# Step 016 | Actor Loss = -0.1168, Critic Loss = 0.1979, AvgReward = 0.6379
# [EP 7] Train dataset expanded: now 2940 samples
#
# ================ EPISODE 8/100 ================
# [Episode 8] Class count → 0: 2000, 1: 940
# [GENERATOR] Early stopping at epoch 6
# [GENERATOR] Epoch 6/100, Loss=0.0283
# 100.00% of data generated by PPO strategy
# [EP 8] Generated synthetic saved: synthetics//syn_ep8.npz
# Step 000 | Actor Loss = -0.0895, Critic Loss = 0.1407, AvgReward = 0.5710
# Step 001 | Actor Loss = 0.0001, Critic Loss = 0.8978, AvgReward = 0.6167
# Step 002 | Actor Loss = 0.1335, Critic Loss = 0.5678, AvgReward = 0.5284
# Step 003 | Actor Loss = 0.0417, Critic Loss = 0.2177, AvgReward = 0.5656
# Step 004 | Actor Loss = -0.0588, Critic Loss = 0.2886, AvgReward = 0.6377
# Step 005 | Actor Loss = -0.0864, Critic Loss = 0.2890, AvgReward = 0.6419
# Step 006 | Actor Loss = -0.0901, Critic Loss = 0.1397, AvgReward = 0.3684
# Step 007 | Actor Loss = 0.0254, Critic Loss = 1.0418, AvgReward = 0.5534
# Step 008 | Actor Loss = -0.1738, Critic Loss = 0.6730, AvgReward = 0.6422
# Step 009 | Actor Loss = 0.1344, Critic Loss = 0.7631, AvgReward = 0.5887
# Step 010 | Actor Loss = -0.0457, Critic Loss = 0.4994, AvgReward = 0.5691
# Step 011 | Actor Loss = -0.1088, Critic Loss = 0.1965, AvgReward = 0.6362
# Step 012 | Actor Loss = -0.1087, Critic Loss = 0.1907, AvgReward = 0.6277
# Step 013 | Actor Loss = -0.0169, Critic Loss = 0.2871, AvgReward = 0.5879
# [PPO] Early stopping at step 14
# Step 013 | Actor Loss = -0.0169, Critic Loss = 0.2871, AvgReward = 0.5879
# [EP 8] Train dataset expanded: now 3040 samples
#
# ================ EPISODE 9/100 ================
# [Episode 9] Class count → 0: 2000, 1: 1040
# [GENERATOR] Early stopping at epoch 6
# [GENERATOR] Epoch 6/100, Loss=0.0276
# 100.00% of data generated by PPO strategy
# [EP 9] Generated synthetic saved: synthetics//syn_ep9.npz
# Step 000 | Actor Loss = -0.0232, Critic Loss = 0.5397, AvgReward = 0.5537
# Step 001 | Actor Loss = -0.1380, Critic Loss = 0.1847, AvgReward = 0.5801
# Step 002 | Actor Loss = 0.1757, Critic Loss = 0.4129, AvgReward = 0.5252
# Step 003 | Actor Loss = -0.1001, Critic Loss = 0.5384, AvgReward = 0.6433
# Step 004 | Actor Loss = -0.0950, Critic Loss = 0.3471, AvgReward = 0.5198
# Step 005 | Actor Loss = -0.1381, Critic Loss = 0.2047, AvgReward = 0.6237
# Step 006 | Actor Loss = -0.0575, Critic Loss = 0.3915, AvgReward = 0.5399
# Step 007 | Actor Loss = -0.1551, Critic Loss = 0.2601, AvgReward = 0.3928
# Step 008 | Actor Loss = -0.0779, Critic Loss = 0.1799, AvgReward = 0.6060
# [PPO] Early stopping at step 9
# Step 008 | Actor Loss = -0.0779, Critic Loss = 0.1799, AvgReward = 0.6060
# [EP 9] Train dataset expanded: now 3140 samples
#
# ================ EPISODE 10/100 ================
# [Episode 10] Class count → 0: 2000, 1: 1140
# [GENERATOR] Early stopping at epoch 6
# [GENERATOR] Epoch 6/100, Loss=0.0265
# 100.00% of data generated by PPO strategy
# [EP 10] Generated synthetic saved: synthetics//syn_ep10.npz
# Step 000 | Actor Loss = 0.0224, Critic Loss = 0.2730, AvgReward = 0.4535
# Step 001 | Actor Loss = -0.0800, Critic Loss = 0.4313, AvgReward = 0.5967
# Step 002 | Actor Loss = -0.0876, Critic Loss = 0.1760, AvgReward = 0.5820
# Step 003 | Actor Loss = 0.1397, Critic Loss = 0.2261, AvgReward = 0.4939
# Step 004 | Actor Loss = -0.1402, Critic Loss = 0.2283, AvgReward = 0.4842
# Step 005 | Actor Loss = -0.1044, Critic Loss = 0.4250, AvgReward = 0.5708
# Step 006 | Actor Loss = 0.0346, Critic Loss = 0.4214, AvgReward = 0.4913
# [PPO] Early stopping at step 7
# Step 006 | Actor Loss = 0.0346, Critic Loss = 0.4214, AvgReward = 0.4913
# [EP 10] Train dataset expanded: now 3240 samples
#
# ================ EPISODE 11/100 ================
# [Episode 11] Class count → 0: 2000, 1: 1240
# [GENERATOR] Early stopping at epoch 6
# [GENERATOR] Epoch 6/100, Loss=0.0260
# 100.00% of data generated by PPO strategy
# [EP 11] Generated synthetic saved: synthetics//syn_ep11.npz
# Step 000 | Actor Loss = -0.0840, Critic Loss = 0.2421, AvgReward = 0.5356
# Step 001 | Actor Loss = -0.0627, Critic Loss = 0.2213, AvgReward = 0.4809
# Step 002 | Actor Loss = -0.1088, Critic Loss = 0.1162, AvgReward = 0.6085
# Step 003 | Actor Loss = 0.2336, Critic Loss = 0.2493, AvgReward = 0.5071
# Step 004 | Actor Loss = 0.2754, Critic Loss = 0.1937, AvgReward = 0.4775
# Step 005 | Actor Loss = -0.0694, Critic Loss = 0.4438, AvgReward = 0.5212
# Step 006 | Actor Loss = 0.0708, Critic Loss = 0.1396, AvgReward = 0.4099
# Step 007 | Actor Loss = 0.0085, Critic Loss = 0.1715, AvgReward = 0.5176
# [PPO] Early stopping at step 8
# Step 007 | Actor Loss = 0.0085, Critic Loss = 0.1715, AvgReward = 0.5176
# [EP 11] Train dataset expanded: now 3340 samples
#
# ================ EPISODE 12/100 ================
# [Episode 12] Class count → 0: 2000, 1: 1340
# [GENERATOR] Early stopping at epoch 7
# [GENERATOR] Epoch 7/100, Loss=0.0252
# 100.00% of data generated by PPO strategy
# [EP 12] Generated synthetic saved: synthetics//syn_ep12.npz
# Step 000 | Actor Loss = -0.0387, Critic Loss = 0.2780, AvgReward = 0.3084
# Step 001 | Actor Loss = -0.0789, Critic Loss = 0.1288, AvgReward = 0.4997
# Step 002 | Actor Loss = 0.0985, Critic Loss = 0.1835, AvgReward = 0.4414
# Step 003 | Actor Loss = 0.2734, Critic Loss = 0.1155, AvgReward = 0.3447
# Step 004 | Actor Loss = -0.0710, Critic Loss = 0.2749, AvgReward = 0.5440
# Step 005 | Actor Loss = 0.2940, Critic Loss = 0.2842, AvgReward = 0.3090
# Step 006 | Actor Loss = 0.2544, Critic Loss = 0.3349, AvgReward = 0.4047
# Step 007 | Actor Loss = 0.2189, Critic Loss = 0.2080, AvgReward = 0.3838
# Step 008 | Actor Loss = 0.0204, Critic Loss = 0.3940, AvgReward = 0.5589
# Step 009 | Actor Loss = 0.2220, Critic Loss = 0.1023, AvgReward = 0.5693
# Step 010 | Actor Loss = 0.0096, Critic Loss = 0.3148, AvgReward = 0.5956
# Step 011 | Actor Loss = 0.2979, Critic Loss = 0.3931, AvgReward = 0.5667
# Step 012 | Actor Loss = -0.0129, Critic Loss = 0.4419, AvgReward = 0.5701
# Step 013 | Actor Loss = 0.1572, Critic Loss = 0.1687, AvgReward = 0.4475
# Step 014 | Actor Loss = 0.1984, Critic Loss = 0.3442, AvgReward = 0.5599
# Step 015 | Actor Loss = 0.1528, Critic Loss = 0.2828, AvgReward = 0.5309
# [PPO] Early stopping at step 16
# Step 015 | Actor Loss = 0.1528, Critic Loss = 0.2828, AvgReward = 0.5309
# [EP 12] Train dataset expanded: now 3440 samples
#
# ================ EPISODE 13/100 ================
# [Episode 13] Class count → 0: 2000, 1: 1440
# [GENERATOR] Epoch 10/100, Loss=0.0247
# [GENERATOR] Early stopping at epoch 14
# [GENERATOR] Epoch 14/100, Loss=0.0244
# 100.00% of data generated by PPO strategy
# [EP 13] Generated synthetic saved: synthetics//syn_ep13.npz
# Step 000 | Actor Loss = 0.0134, Critic Loss = 0.4559, AvgReward = 0.5824
# Step 001 | Actor Loss = 0.0025, Critic Loss = 0.1803, AvgReward = 0.5600
# Step 002 | Actor Loss = 0.2979, Critic Loss = 1.0179, AvgReward = 0.5486
# Step 003 | Actor Loss = -0.0147, Critic Loss = 0.7469, AvgReward = 0.6228
# Step 004 | Actor Loss = 0.2823, Critic Loss = 0.1151, AvgReward = 0.6124
# Step 005 | Actor Loss = -0.0464, Critic Loss = 0.2711, AvgReward = 0.6233
# Step 006 | Actor Loss = 0.0431, Critic Loss = 0.2308, AvgReward = 0.6310
# Step 007 | Actor Loss = 0.1619, Critic Loss = 0.3594, AvgReward = 0.6265
# Step 008 | Actor Loss = 0.0966, Critic Loss = 0.2760, AvgReward = 0.6245
# Step 009 | Actor Loss = 0.1610, Critic Loss = 0.3239, AvgReward = 0.6341
# Step 010 | Actor Loss = 0.0157, Critic Loss = 0.1945, AvgReward = 0.6246
# Step 011 | Actor Loss = 0.1386, Critic Loss = 1.6927, AvgReward = 0.6198
# Step 012 | Actor Loss = 0.3044, Critic Loss = 0.3520, AvgReward = 0.5998
# Step 013 | Actor Loss = 0.1879, Critic Loss = 0.1400, AvgReward = 0.5890
# Step 014 | Actor Loss = 0.1078, Critic Loss = 0.2652, AvgReward = 0.6000
# [PPO] Early stopping at step 15
# Step 014 | Actor Loss = 0.1078, Critic Loss = 0.2652, AvgReward = 0.6000
# [EP 13] Train dataset expanded: now 3540 samples
#
# ================ EPISODE 14/100 ================
# [Episode 14] Class count → 0: 2000, 1: 1540
# [GENERATOR] Early stopping at epoch 8
# [GENERATOR] Epoch 8/100, Loss=0.0239
# 100.00% of data generated by PPO strategy
# [EP 14] Generated synthetic saved: synthetics//syn_ep14.npz
# Step 000 | Actor Loss = 0.0736, Critic Loss = 0.1119, AvgReward = 0.6122
# Step 001 | Actor Loss = 0.0510, Critic Loss = 0.3093, AvgReward = 0.6049
# Step 002 | Actor Loss = 0.0811, Critic Loss = 0.1966, AvgReward = 0.6215
# Step 003 | Actor Loss = 0.0831, Critic Loss = 0.5326, AvgReward = 0.6355
# Step 004 | Actor Loss = 0.1506, Critic Loss = 0.2039, AvgReward = 0.5925
# Step 005 | Actor Loss = 0.0340, Critic Loss = 0.2949, AvgReward = 0.6023
# Step 006 | Actor Loss = 0.1347, Critic Loss = 0.0952, AvgReward = 0.6045
# Step 007 | Actor Loss = -0.0734, Critic Loss = 0.1056, AvgReward = 0.6099
# Step 008 | Actor Loss = 0.2568, Critic Loss = 0.1433, AvgReward = 0.5911
# [PPO] Early stopping at step 9
# Step 008 | Actor Loss = 0.2568, Critic Loss = 0.1433, AvgReward = 0.5911
# [EP 14] Train dataset expanded: now 3640 samples
#
# ================ EPISODE 15/100 ================
# [Episode 15] Class count → 0: 2000, 1: 1640
# [GENERATOR] Early stopping at epoch 7
# [GENERATOR] Epoch 7/100, Loss=0.0234
# 100.00% of data generated by PPO strategy
# [EP 15] Generated synthetic saved: synthetics//syn_ep15.npz
# Step 000 | Actor Loss = 0.2974, Critic Loss = 0.1059, AvgReward = 0.5984
# Step 001 | Actor Loss = 0.0602, Critic Loss = 0.4725, AvgReward = 0.6044
# Step 002 | Actor Loss = -0.0706, Critic Loss = 0.4005, AvgReward = 0.6326
# Step 003 | Actor Loss = -0.0384, Critic Loss = 0.1513, AvgReward = 0.6318
# Step 004 | Actor Loss = 0.0089, Critic Loss = 0.0852, AvgReward = 0.6403
# Step 005 | Actor Loss = 0.0412, Critic Loss = 0.0704, AvgReward = 0.6202
# Step 006 | Actor Loss = 0.0778, Critic Loss = 0.2294, AvgReward = 0.6259
# Step 007 | Actor Loss = 0.1974, Critic Loss = 0.1579, AvgReward = 0.5781
# Step 008 | Actor Loss = 0.0095, Critic Loss = 0.1750, AvgReward = 0.6233
# Step 009 | Actor Loss = 0.1480, Critic Loss = 0.1613, AvgReward = 0.6299
# [PPO] Early stopping at step 10
# Step 009 | Actor Loss = 0.1480, Critic Loss = 0.1613, AvgReward = 0.6299
# [EP 15] Train dataset expanded: now 3740 samples
#
# ================ EPISODE 16/100 ================
# [Episode 16] Class count → 0: 2000, 1: 1740
# [GENERATOR] Early stopping at epoch 6
# [GENERATOR] Epoch 6/100, Loss=0.0227
# 100.00% of data generated by PPO strategy
# [EP 16] Generated synthetic saved: synthetics//syn_ep16.npz
# Step 000 | Actor Loss = 0.0695, Critic Loss = 0.3441, AvgReward = 0.6419
# Step 001 | Actor Loss = 0.2751, Critic Loss = 0.8743, AvgReward = 0.6341
# Step 002 | Actor Loss = -0.0107, Critic Loss = 0.6381, AvgReward = 0.6241
# Step 003 | Actor Loss = 0.2096, Critic Loss = 0.0859, AvgReward = 0.6132
# Step 004 | Actor Loss = 0.0959, Critic Loss = 0.1621, AvgReward = 0.6104
# Step 005 | Actor Loss = -0.0464, Critic Loss = 0.3101, AvgReward = 0.5895
# [PPO] Early stopping at step 6
# Step 005 | Actor Loss = -0.0464, Critic Loss = 0.3101, AvgReward = 0.5895
# [EP 16] Train dataset expanded: now 3840 samples
#
# ================ EPISODE 17/100 ================
# [Episode 17] Class count → 0: 2000, 1: 1840
# [GENERATOR] Early stopping at epoch 7
# [GENERATOR] Epoch 7/100, Loss=0.0226
# 100.00% of data generated by PPO strategy
# [EP 17] Generated synthetic saved: synthetics//syn_ep17.npz
# Step 000 | Actor Loss = 0.0645, Critic Loss = 0.1391, AvgReward = 0.6235
# Step 001 | Actor Loss = -0.0131, Critic Loss = 0.1787, AvgReward = 0.6177
# Step 002 | Actor Loss = 0.1338, Critic Loss = 0.3768, AvgReward = 0.6108
# Step 003 | Actor Loss = 0.0170, Critic Loss = 0.1310, AvgReward = 0.6141
# Step 004 | Actor Loss = 0.2288, Critic Loss = 0.1954, AvgReward = 0.6082
# Step 005 | Actor Loss = -0.0641, Critic Loss = 0.0903, AvgReward = 0.6221
# [PPO] Early stopping at step 6
# Step 005 | Actor Loss = -0.0641, Critic Loss = 0.0903, AvgReward = 0.6221
# [EP 17] Train dataset expanded: now 3940 samples
#
# ================ EPISODE 18/100 ================
# [Episode 18] Class count → 0: 2000, 1: 1940
# [GENERATOR] Epoch 10/100, Loss=0.0217
# [GENERATOR] Early stopping at epoch 10
# [GENERATOR] Epoch 10/100, Loss=0.0217
# 100.00% of data generated by PPO strategy
# [EP 18] Generated synthetic saved: synthetics//syn_ep18.npz
# Step 000 | Actor Loss = 0.0446, Critic Loss = 0.1081, AvgReward = 0.6407
# Step 001 | Actor Loss = -0.0228, Critic Loss = 0.1642, AvgReward = 0.6381
# Step 002 | Actor Loss = 0.0542, Critic Loss = 0.2214, AvgReward = 0.6105
# Step 003 | Actor Loss = -0.0072, Critic Loss = 0.3930, AvgReward = 0.6388
# Step 004 | Actor Loss = 0.2591, Critic Loss = 0.1327, AvgReward = 0.6427
# Step 005 | Actor Loss = 0.0650, Critic Loss = 0.2871, AvgReward = 0.6346
# Step 006 | Actor Loss = 0.0367, Critic Loss = 0.3690, AvgReward = 0.6493
# Step 007 | Actor Loss = -0.0732, Critic Loss = 0.2081, AvgReward = 0.6189
# Step 008 | Actor Loss = 0.1692, Critic Loss = 0.2207, AvgReward = 0.6015
# Step 009 | Actor Loss = -0.0480, Critic Loss = 0.0548, AvgReward = 0.6247
# Step 010 | Actor Loss = -0.1445, Critic Loss = 0.2552, AvgReward = 0.6422
# Step 011 | Actor Loss = 0.1512, Critic Loss = 0.1099, AvgReward = 0.5919
# [PPO] Early stopping at step 12
# Step 011 | Actor Loss = 0.1512, Critic Loss = 0.1099, AvgReward = 0.5919
# [EP 18] Train dataset expanded: now 4040 samples
#
# ================ EPISODE 19/100 ================
# [Episode 19] Class count → 0: 2000, 1: 2040
# Dataset is now balanced. Stopping synthetic generation.

# %%
final_detector = ViTransformerDetector(embedder=embedder).to(DEVICE)
optimizer_final = torch.optim.Adam(final_detector.parameters(), lr=1e-3)
criterion = nn.BCELoss()
num_epochs_final = 100
early_stopper.reset()

for epoch in range(num_epochs_final):
    loss = train_detector(final_detector, train_loader, optimizer_final, criterion, DEVICE)
    print(f"[FINAL DETECTOR] Epoch {epoch+1}/{num_epochs_final}, Loss={loss:.4f}")

    # Check early stopping
    early_stopper.step(loss)

    if early_stopper.early_stop:
        print(f"[FINAL DETECTOR] Early stopping at epoch {epoch+1}")
        print(f"[FINAL DETECTOR] Epoch {epoch+1}/{num_epochs_final}, Loss={loss:.4f}")
        break
# Out:
# [FINAL DETECTOR] Epoch 1/100, Loss=0.1555
# [FINAL DETECTOR] Epoch 2/100, Loss=0.0562
# [FINAL DETECTOR] Epoch 3/100, Loss=0.0597
# [FINAL DETECTOR] Epoch 4/100, Loss=0.0347
# [FINAL DETECTOR] Epoch 5/100, Loss=0.0331
# [FINAL DETECTOR] Epoch 6/100, Loss=0.0494
# [FINAL DETECTOR] Epoch 7/100, Loss=0.0406
# [FINAL DETECTOR] Epoch 8/100, Loss=0.0345
# [FINAL DETECTOR] Epoch 9/100, Loss=0.0184
# [FINAL DETECTOR] Epoch 10/100, Loss=0.0292
# [FINAL DETECTOR] Epoch 11/100, Loss=0.0112
# [FINAL DETECTOR] Epoch 12/100, Loss=0.0092
# [FINAL DETECTOR] Epoch 13/100, Loss=0.0017
# [FINAL DETECTOR] Epoch 14/100, Loss=0.0097
# [FINAL DETECTOR] Epoch 15/100, Loss=0.0136
# [FINAL DETECTOR] Epoch 16/100, Loss=0.0072
# [FINAL DETECTOR] Epoch 17/100, Loss=0.0083
# [FINAL DETECTOR] Epoch 18/100, Loss=0.0026
# [FINAL DETECTOR] Early stopping at epoch 18
# [FINAL DETECTOR] Epoch 18/100, Loss=0.0026

# %%
evaluate_model(final_detector, test_loader, DEVICE, threshold=0.3)

# Save final detector
torch.save(final_detector.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_detector_final.pth")
print(f"Final detector saved to {MODEL_DIR}/{DATASET_NAME}_detector_final.pth")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00      3000
#      Class 1       0.99      0.98      0.98       360
#
#     accuracy                           1.00      3360
#    macro avg       0.99      0.99      0.99      3360
# weighted avg       1.00      1.00      1.00      3360
#
# AUC-ROC: 0.9997
# Final detector saved to OCT2017_models//OCT2017_detector_final.pth

# %%
torch.save(actor.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_actor.pth")
print(f"PPO Actor saved to {MODEL_DIR}/{DATASET_NAME}_actor.pth")

torch.save(critic.state_dict(), f"{MODEL_DIR}/{DATASET_NAME}_critic.pth")
print(f"PPO Critic saved to {MODEL_DIR}/{DATASET_NAME}_critic.pth")
# Out:
# PPO Actor saved to OCT2017_models//OCT2017_actor.pth
# PPO Critic saved to OCT2017_models//OCT2017_critic.pth

# %%
import shutil

synthetics_folder = "/kaggle/working/synthetics"
synthetics_zip = f"{DATASET_NAME}_synthetics"

shutil.make_archive(synthetics_zip, 'zip', synthetics_folder)
# Out:
# '/kaggle/working/OCT2017_synthetics.zip'

# %%
import shutil

models_folder = f"/kaggle/working/{DATASET_NAME}_models"
models_zip = f"{DATASET_NAME}_models1"

shutil.make_archive(models_zip, 'zip', models_folder)
# Out:
# '/kaggle/working/OCT2017_models1.zip'

# %%
strict_dataset, strict_loader, _, _ = load_train_test(
    f"{DATASET_DIR}/{DATASET_NAME}/BMAD-AD_{DATASET_NAME}_train.npz", device=DEVICE, batch_size=100, test_size=0
)

# Test set evaluation
evaluate_model(final_detector, strict_loader, DEVICE, threshold=0.3)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00      5000
#      Class 1       0.99      0.99      0.99       600
#
#     accuracy                           1.00      5600
#    macro avg       1.00      0.99      0.99      5600
# weighted avg       1.00      1.00      1.00      5600
#
# AUC-ROC: 0.9998

# %%
strict_dataset, strict_loader, _, _ = load_train_test(
    f"{DATASET_DIR}/{DATASET_NAME}/BMAD-AD_{DATASET_NAME}_valid.npz", device=DEVICE, batch_size=100, test_size=0
)

# Test set evaluation
evaluate_model(final_detector, strict_loader, DEVICE, threshold=0.3)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      1.00      1.00      1250
#      Class 1       0.98      0.99      0.98       150
#
#     accuracy                           1.00      1400
#    macro avg       0.99      0.99      0.99      1400
# weighted avg       1.00      1.00      1.00      1400
#
# AUC-ROC: 0.9999

# %%
# import matplotlib.pyplot as plt
# from torchvision import transforms
# from torch.utils.data import TensorDatasetss

def preview_images(loader, model=None, device='cpu', num_images=5):
    for images, labels in loader:
        images = images[:num_images]
        labels = labels[:num_images]

        if model is None:
            # Chỉ hiển thị ảnh
            imgs_np = images.cpu().numpy()
            labels_np = labels.cpu().numpy()
            imgs_np = np.clip(imgs_np, 0, 1)
            n = imgs_np.shape[0]
            fig, axes = plt.subplots(1, n, figsize=(3*n, 3))
            if n == 1:
                axes = [axes]
            for j in range(n):
                label = int(labels_np[j])
                axes[j].imshow(imgs_np[j].transpose(1, 2, 0))
                axes[j].set_title(f'[{label}] Image {j}')
                axes[j].axis('off')
            plt.tight_layout()
            plt.show()
        else:
            # Hiển thị Original vs Reconstructed
            model.eval()
            with torch.no_grad():
                images = images.to(device)
                labels = labels.to(device)
                reconstructed, _, _ = model(images, labels.unsqueeze(1))

            orig = images.cpu().numpy()
            recon = reconstructed.cpu().numpy()
            labels_np = labels.cpu().numpy()
            orig = np.clip(orig, 0, 1)
            recon = np.clip(recon, 0, 1)

            n = orig.shape[0]
            fig, axes = plt.subplots(2, n, figsize=(4*n, 8))
            if n == 1:
                axes = axes.reshape(2, 1)

            for j in range(n):
                label = int(labels_np[j])
                axes[0, j].imshow(orig[j].transpose(1, 2, 0))
                axes[0, j].set_title(f'[{label}] Org-{j}')
                axes[0, j].axis('off')

                axes[1, j].imshow(recon[j].transpose(1, 2, 0))
                axes[1, j].set_title(f'[{label}] Recon-{j}')
                axes[1, j].axis('off')
            plt.tight_layout()
            plt.show()

        break  # chỉ lấy 1 batch

def load_data(data, batch_num=64, is_shuffle=True):
    images = data['images']  # shape: (N, H, W, C)
    labels = data['labels']

    # Define transform
    transform = transforms.Compose([
        transforms.ToPILImage(),            # Chuyển numpy array -> PIL Image
        transforms.Resize((256, 256)),      # Resize về 256x256
        transforms.ToTensor()               # Chuyển PIL Image -> Tensor [0,1]
    ])

    # Áp dụng transform cho từng ảnh
    X = torch.stack([transform(img) for img in images])

    # Chuyển labels sang tensor
    y = torch.tensor(labels, dtype=torch.float32)

    # Tạo dataset & dataloader
    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=batch_num, shuffle=is_shuffle)

    return loader

# %%
syn_data = np.load(f"/kaggle/working/synthetics/syn_ep{len(os.listdir("/kaggle/working/synthetics"))}.npz", allow_pickle=True)
syn_loader = load_data(syn_data)

# %%
preview_images(syn_loader)

# %%
t_data = np.load(f"{DATASET_DIR}/{DATASET_NAME}/BMAD-AD_{DATASET_NAME}_valid.npz", allow_pickle=True)
t_loader = load_data(t_data)

# %%
preview_images(t_loader)
